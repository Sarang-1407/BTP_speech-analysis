# %% [markdown]
# #Importing Libraries and downloading required packages

# %%
import re
import nltk
import string
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.probability import FreqDist
from wordcloud import WordCloud
from collections import defaultdict
import operator

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# #Defining necessary functions

# %% [markdown]
# ###Defining a function for basic text preprocessing

# %%
def text_preprocessing(raw):
  # lower case
  raw = raw.lower()
  # remove numbers
  raw = re.sub(r'\d+', '', raw)
  # remove punctuation
  raw = re.sub(r'[^\w\s]', '', raw)
  # white space removal
  raw = raw.strip()
  #removing any non alphanumeric characters
  raw = re.sub('\W', ' ', raw)  
  #removing extra white spaces
  raw = re.sub('\s+', ' ', raw) 
  #removing chapter numbers and running sections
  raw = re.sub('chapter \w*', '', raw)   
  return (raw)

# %% [markdown]
# ###Function to calculate frequency

# %%
def freq(tokens):
# frequency of tokens
  freq = {}
  for t in tokens:
    if t in freq:
      freq[t]+=1
    else:
      freq[t]=1
  return freq

# %% [markdown]
# ###Function to plot frequency graph

# %%
def freq_graph(tokens):
#frequency graph
  FreqDist(tokens)
  all_fdist = FreqDist(tokens).most_common(60)

  all_fdist = pd.Series(dict(all_fdist))

  fig, ax = plt.subplots(figsize=(10,10))

  all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)
  plt.xticks(rotation=90)

# %% [markdown]
# ###Function to generate and display word cloud

# %%
def word_cloud(freq):
  wc = WordCloud(height = 1000, width = 1500, background_color = 'white', max_words = 1000)
  wc.generate_from_frequencies(freq)
  return wc

# %%
def showCloud(cloud):
    plt.figure(figsize=(10,10))
    plt.imshow(cloud)
    plt.axis('off')

# %% [markdown]
# ###Function to remove stop words

# %%
def stopwords_text(text):
  stop_words = set(nltk.corpus.stopwords.words('english'))
  x = 65
  y = 97
  for i in range(26):
    stop_words.add(chr(x))
    stop_words.add(chr(y))
    x += 1
    y += 1
  tokens = word_tokenize(text)
  result = [i for i in tokens if not i in stop_words]
  return result

# %% [markdown]
# ###Function to count words

# %%
words ={}
def word_counter(text):
  words.clear()
  for word in text.split():
    if(len(word)not in words ):
      words[len(word)]=1
    else:
      words[len(word)]+=1

# %% [markdown]
# #Loading and Frequency Analysis of a speech

# %% [markdown]
# ###Opening a txt file

# %% [markdown]
# ####Text T1

# %%
f = open('/content/Shashi Tharoor.txt')
text = f.read()

# %% [markdown]
# ####Text T2

# %%
f2 = open('/content/Shashi Tharoor2.txt')
text2 = f2.read()

# %% [markdown]
# ###Text Preprocessing

# %%
t1 = text_preprocessing(text)

# %%
t2 = text_preprocessing(text2)

# %% [markdown]
# ###Tokenisation

# %%
t1tokens = nltk.word_tokenize(t1)
t1tokens
# Out:
# ['madam',
#  'president',
#  'and',
#  'gentlemen',
#  'ladies',
#  'of',
#  'the',
#  'house',
#  'i',
#  'standing',
#  'here',
#  'with',
#  'eight',
#  'minutes',
#  'in',
#  'my',
#  'hands',
#  'in',
#  'this',
#  'venerable',
#  'and',
#  'rather',
#  'magnificent',
#  'institution',
#  'i',
#  'was',
#  'going',
#  'to',
#  'assure',
#  'you',
#  'that',
#  'i',
#  'belong',
#  'to',
#  'the',
#  'henry',
#  'viii',
#  'school',
#  'of',
#  'public',
#  'speaking',
#  'that',
#  'as',
#  'henry',
#  'viii',
#  'said',
#  'to',
#  'his',
#  'wives',
#  'i',
#  'shall',
#  'not',
#  'keep',
#  'you',
#  'long',
#  'but',
#  'now',
#  'finding',
#  'myself',
#  'the',
#  'seventh',
#  'speaker',
#  'out',
#  'of',
#  'eight',
#  'in',
#  'what',
#  'must',
#  'already',
#  'seem',
#  'a',
#  'rather',
#  'long',
#  'evening',
#  'to',
#  'you',
#  'i',
#  'rather',
#  'feel',
#  'like',
#  'henry',
#  'viiis',
#  'the',
#  'last',
#  'wife',
#  'i',
#  'more',
#  'or',
#  'less',
#  'know',
#  'whats',
#  'expected',
#  'of',
#  'me',
#  'but',
#  'i',
#  'am',
#  'not',
#  'sure',
#  'how',
#  'to',
#  'do',
#  'it',
#  'any',
#  'differently',
#  'perhaps',
#  'what',
#  'i',
#  'should',
#  'do',
#  'is',
#  'really',
#  'try',
#  'and',
#  'pay',
#  'attention',
#  'to',
#  'the',
#  'arguments',
#  'that',
#  'have',
#  'advanced',
#  'by',
#  'the',
#  'opposition',
#  'today',
#  'we',
#  'had',
#  'for',
#  'example',
#  'sir',
#  'richard',
#  'ottaway',
#  'suggesting',
#  'challenging',
#  'the',
#  'very',
#  'idea',
#  'that',
#  'it',
#  'could',
#  'be',
#  'argued',
#  'that',
#  'the',
#  'economic',
#  'situation',
#  'of',
#  'the',
#  'colonies',
#  'was',
#  'actually',
#  'worsened',
#  'by',
#  'the',
#  'experience',
#  'of',
#  'british',
#  'colonialism',
#  'well',
#  'i',
#  'stand',
#  'to',
#  'offer',
#  'you',
#  'the',
#  'indian',
#  'example',
#  'sir',
#  'richard',
#  'india',
#  'share',
#  'of',
#  'the',
#  'world',
#  'economy',
#  'when',
#  'britain',
#  'arrived',
#  'on',
#  'its',
#  'shores',
#  'was',
#  'by',
#  'the',
#  'time',
#  'the',
#  'british',
#  'left',
#  'it',
#  'was',
#  'down',
#  'to',
#  'below',
#  'why',
#  'simply',
#  'because',
#  'india',
#  'had',
#  'been',
#  'governed',
#  'for',
#  'the',
#  'benefit',
#  'of',
#  'britain',
#  'britains',
#  'rise',
#  'for',
#  'years',
#  'was',
#  'financed',
#  'by',
#  'its',
#  'depredations',
#  'in',
#  'india',
#  'in',
#  'fact',
#  'britains',
#  'industrial',
#  'revolution',
#  'was',
#  'actually',
#  'premised',
#  'upon',
#  'the',
#  'deindustrialization',
#  'of',
#  'india',
#  'the',
#  'handloom',
#  'weavers',
#  'for',
#  'example',
#  'famed',
#  'across',
#  'the',
#  'world',
#  'whose',
#  'products',
#  'were',
#  'exported',
#  'around',
#  'the',
#  'world',
#  'britain',
#  'came',
#  'right',
#  'in',
#  'there',
#  'were',
#  'actually',
#  'these',
#  'weavers',
#  'making',
#  'fine',
#  'muslin',
#  'as',
#  'light',
#  'as',
#  'woven',
#  'wear',
#  'it',
#  'was',
#  'said',
#  'and',
#  'britain',
#  'came',
#  'right',
#  'in',
#  'smashed',
#  'their',
#  'thumbs',
#  'broke',
#  'their',
#  'looms',
#  'imposed',
#  'tariffs',
#  'and',
#  'duties',
#  'on',
#  'their',
#  'cloth',
#  'and',
#  'products',
#  'and',
#  'started',
#  'of',
#  'course',
#  'taking',
#  'the',
#  'raw',
#  'materials',
#  'from',
#  'india',
#  'and',
#  'shipping',
#  'back',
#  'manufactured',
#  'cloth',
#  'flooding',
#  'the',
#  'worlds',
#  'markets',
#  'with',
#  'what',
#  'became',
#  'the',
#  'products',
#  'of',
#  'the',
#  'dark',
#  'and',
#  'satanic',
#  'mills',
#  'of',
#  'the',
#  'victoria',
#  'in',
#  'england',
#  'that',
#  'meant',
#  'that',
#  'the',
#  'weavers',
#  'in',
#  'india',
#  'became',
#  'beggars',
#  'and',
#  'india',
#  'went',
#  'from',
#  'being',
#  'a',
#  'world',
#  'famous',
#  'exporter',
#  'of',
#  'finished',
#  'cloth',
#  'into',
#  'an',
#  'importer',
#  'when',
#  'from',
#  'having',
#  'of',
#  'the',
#  'world',
#  'trade',
#  'to',
#  'less',
#  'than',
#  'meanwhile',
#  'colonialists',
#  'like',
#  'robert',
#  'clive',
#  'bought',
#  'their',
#  'rotten',
#  'boroughs',
#  'in',
#  'england',
#  'on',
#  'the',
#  'proceeds',
#  'of',
#  'their',
#  'loot',
#  'in',
#  'india',
#  'while',
#  'taking',
#  'the',
#  'hindi',
#  'word',
#  'loot',
#  'into',
#  'their',
#  'dictionary',
#  'as',
#  'well',
#  'as',
#  'their',
#  'habits',
#  'and',
#  'the',
#  'british',
#  'had',
#  'the',
#  'gall',
#  'to',
#  'call',
#  'him',
#  'clive',
#  'of',
#  'india',
#  'as',
#  'if',
#  'he',
#  'belonged',
#  'to',
#  'the',
#  'country',
#  'when',
#  'all',
#  'he',
#  'really',
#  'did',
#  'was',
#  'to',
#  'ensure',
#  'that',
#  'much',
#  'of',
#  'the',
#  'country',
#  'belonged',
#  'to',
#  'him',
#  'by',
#  'the',
#  'end',
#  'of',
#  'the',
#  'th',
#  'century',
#  'the',
#  'fact',
#  'is',
#  'that',
#  'india',
#  'was',
#  'already',
#  'britains',
#  'biggest',
#  'cash',
#  'cow',
#  'the',
#  'worlds',
#  'biggest',
#  'purchaser',
#  'of',
#  'british',
#  'goods',
#  'and',
#  'exports',
#  'and',
#  'the',
#  'source',
#  'for',
#  'highly',
#  'paid',
#  'employment',
#  'for',
#  'british',
#  'civil',
#  'servants',
#  'we',
#  'literally',
#  'paid',
#  'for',
#  'our',
#  'own',
#  'oppression',
#  'and',
#  'as',
#  'has',
#  'been',
#  'pointed',
#  'out',
#  'the',
#  'wealthy',
#  'victorian',
#  'british',
#  'families',
#  'that',
#  'made',
#  'their',
#  'money',
#  'out',
#  'of',
#  'the',
#  'slave',
#  'economy',
#  'one',
#  'fifth',
#  'of',
#  'the',
#  'elites',
#  'of',
#  'the',
#  'wealthy',
#  'class',
#  'in',
#  'britain',
#  'in',
#  'the',
#  'th',
#  'century',
#  'owed',
#  'their',
#  'money',
#  'to',
#  'transporting',
#  'million',
#  'africans',
#  'across',
#  'the',
#  'waters',
#  'and',
#  'in',
#  'fact',
#  'in',
#  'when',
#  'slavery',
#  'was',
#  'abolished',
#  'and',
#  'what',
#  'happened',
#  'was',
#  'that',
#  'a',
#  'compensation',
#  'of',
#  'million',
#  'pounds',
#  'was',
#  'paid',
#  'not',
#  'as',
#  'reparations',
#  'to',
#  'those',
#  'who',
#  'had',
#  'lost',
#  'their',
#  'lives',
#  'or',
#  'who',
#  'had',
#  'suffered',
#  'or',
#  'been',
#  'oppressed',
#  'by',
#  'slavery',
#  'but',
#  'to',
#  'those',
#  'who',
#  'had',
#  'lost',
#  'their',
#  'property',
#  'i',
#  'was',
#  'struck',
#  'by',
#  'the',
#  'fact',
#  'that',
#  'your',
#  'wifi',
#  'password',
#  'at',
#  'this',
#  'union',
#  'commemorates',
#  'the',
#  'name',
#  'of',
#  'mr',
#  'gladstone',
#  'the',
#  'great',
#  'liberal',
#  'hero',
#  'well',
#  'i',
#  'am',
#  'very',
#  'sorry',
#  'his',
#  'family',
#  'was',
#  'one',
#  'of',
#  'those',
#  'who',
#  'benefited',
#  'from',
#  'this',
#  'compensation',
#  'staying',
#  'with',
#  'india',
#  'between',
#  'million',
#  'and',
#  'million',
#  'indians',
#  'died',
#  'of',
#  'starvation',
#  'in',
#  'british',
#  'induced',
#  'famines',
#  'the',
#  'most',
#  'famous',
#  'example',
#  'was',
#  'of',
#  'course',
#  'was',
#  'the',
#  'great',
#  'bengal',
#  'famine',
#  'during',
#  'the',
#  'world',
#  'war',
#  'ii',
#  'when',
#  'million',
#  'people',
#  'died',
#  'because',
#  'winston',
#  'churchill',
#  'deliberately',
#  'as',
#  'a',
#  'matter',
#  'of',
#  'written',
#  'policy',
#  'proceeded',
#  'to',
#  'divert',
#  'essential',
#  'supplies',
#  'from',
#  'civilians',
#  'in',
#  'bengal',
#  'to',
#  'sturdy',
#  'tummies',
#  'and',
#  'europeans',
#  'as',
#  'reserve',
#  'stockpiles',
#  'he',
#  'said',
#  'that',
#  'the',
#  'starvation',
#  'of',
#  'anyway',
#  'underfed',
#  'bengalis',
#  'mattered',
#  'much',
#  'less',
#  'than',
#  'that',
#  'of',
#  'sturdy',
#  'greeks',
#  'churchills',
#  'actual',
#  'quote',
#  'and',
#  'when',
#  'conscious',
#  'stricken',
#  'british',
#  'officials',
#  'wrote',
#  'to',
#  'him',
#  'pointing',
#  'out',
#  'that',
#  'people',
#  'were',
#  'dying',
#  'because',
#  'of',
#  'this',
#  'decision',
#  'he',
#  'peevishly',
#  'wrote',
#  'in',
#  'the',
#  'margins',
#  'of',
#  'file',
#  'why',
#  'hasnt',
#  'gandhi',
#  'died',
#  'yet',
#  'so',
#  'all',
#  'notions',
#  'that',
#  'the',
#  'british',
#  'were',
#  'trying',
#  'to',
#  'do',
#  'their',
#  'colonial',
#  'enterprise',
#  'out',
#  'of',
#  'enlightened',
#  'despotism',
#  'to',
#  'try',
#  'and',
#  'bring',
#  'the',
#  'benefits',
#  'of',
#  'colonialism',
#  'and',
#  'civilization',
#  'to',
#  'the',
#  'benighted',
#  'even',
#  'i',
#  'am',
#  'sorry',
#  'churchills',
#  'conduct',
#  'in',
#  'is',
#  'simply',
#  'one',
#  'example',
#  'of',
#  'many',
#  'that',
#  'gave',
#  'light',
#  'to',
#  'this',
#  'myth',
#  'as',
#  'others',
#  'have',
#  'said',
#  'on',
#  'the',
#  'proposition',
#  'violence',
#  'and',
#  'racism',
#  'were',
#  'the',
#  'reality',
#  'of',
#  'the',
#  'colonial',
#  'experience',
#  'and',
#  'no',
#  'wonder',
#  'that',
#  'the',
#  'sun',
#  'never',
#  'set',
#  'on',
#  'the',
#  'british',
#  'empire',
#  'because',
#  'even',
#  'god',
#  'couldnt',
#  'trust',
#  'the',
#  'english',
#  'in',
#  'the',
#  'dark',
#  'let',
#  'me',
#  'take',
#  'the',
#  'world',
#  'war',
#  'i',
#  'as',
#  'a',
#  'very',
#  'concrete',
#  'example',
#  'since',
#  'the',
#  'first',
#  'speaker',
#  'mr',
#  'lee',
#  'suggested',
#  'these',
#  'things',
#  'couldnt',
#  'be',
#  'quantified',
#  'well',
#  'let',
#  'me',
#  'quantify',
#  'world',
#  'war',
#  'i',
#  'for',
#  'you',
#  'again',
#  'i',
#  'am',
#  'sorry',
#  'from',
#  'an',
#  'indian',
#  'perspective',
#  'as',
#  'others',
#  'have',
#  'spoken',
#  'about',
#  'the',
#  'countries',
#  'onesixth',
#  'of',
#  'all',
#  'the',
#  'british',
#  'forces',
#  'that',
#  'fought',
#  'in',
#  'the',
#  'war',
#  'were',
#  'indian',
#  'indians',
#  'actually',
#  'lost',
#  'their',
#  'lives',
#  'in',
#  'that',
#  'war',
#  'were',
#  'wounded',
#  'and',
#  'another',
#  'remained',
#  'missing',
#  'or',
#  'in',
#  'prison',
#  'indian',
#  'taxpayers',
#  'had',
#  'to',
#  'cough',
#  'up',
#  'million',
#  'pounds',
#  'in',
#  'that',
#  'times',
#  'money',
#  'india',
#  'supplied',
#  'million',
#  'rounds',
#  'of',
#  'ammunition',
#  'rifles',
#  'and',
#  'machine',
#  'guns',
#  'million',
#  'garments',
#  'were',
#  'stitched',
#  'and',
#  'sent',
#  'out',
#  'of',
#  'india',
#  'and',
#  'million',
#  'indian',
#  'personnel',
#  'served',
#  'in',
#  'this',
#  'war',
#  'i',
#  'know',
#  'all',
#  'this',
#  'because',
#  'of',
#  'course',
#  'the',
#  'commemoration',
#  'of',
#  'the',
#  'centenary',
#  'has',
#  'just',
#  'taken',
#  'place',
#  'but',
#  'not',
#  'just',
#  'that',
#  'india',
#  'had',
#  'to',
#  'supply',
#  'animals',
#  'million',
#  'tons',
#  'of',
#  'supplies',
#  'and',
#  'in',
#  'the',
#  'end',
#  'the',
#  'total',
#  'value',
#  'of',
#  'everything',
#  'that',
#  'was',
#  'taken',
#  'out',
#  'of',
#  'india',
#  'india',
#  'and',
#  'india',
#  'by',
#  'the',
#  'way',
#  'suffering',
#  'from',
#  'recession',
#  'at',
#  'that',
#  'time',
#  'and',
#  'poverty',
#  'and',
#  'hunger',
#  'was',
#  'in',
#  'todays',
#  'money',
#  'billion',
#  'pounds',
#  'you',
#  'want',
#  'quantification',
#  'its',
#  'available',
#  'world',
#  'war',
#  'ii',
#  'it',
#  'was',
#  'even',
#  'worse',
#  'million',
#  'indians',
#  'in',
#  ...]

# %%
t2tokens = nltk.word_tokenize(t2)
t2tokens
# Out:
# ['one',
#  'of',
#  'the',
#  'more',
#  'insidious',
#  'challenges',
#  'of',
#  'colonialism',
#  'is',
#  'the',
#  'extent',
#  'to',
#  'which',
#  'our',
#  'minds',
#  'are',
#  'colonized',
#  'as',
#  'well',
#  'and',
#  'that',
#  'colonization',
#  'of',
#  'a',
#  'mind',
#  'takes',
#  'some',
#  'growing',
#  'out',
#  'of',
#  'for',
#  'us',
#  'for',
#  'some',
#  'of',
#  'us',
#  'well',
#  'never',
#  'really',
#  'grow',
#  'out',
#  'of',
#  'it',
#  'i',
#  'mean',
#  'i',
#  'do',
#  'know',
#  'that',
#  'there',
#  'are',
#  'the',
#  'many',
#  'who',
#  'cant',
#  'help',
#  'as',
#  'it',
#  'were',
#  'the',
#  'identification',
#  'with',
#  'things',
#  'anglophone',
#  'and',
#  'anglophile',
#  'because',
#  'thats',
#  'really',
#  'what',
#  'they',
#  'were',
#  'schooled',
#  'to',
#  'appreciate',
#  'i',
#  'have',
#  'argued',
#  'in',
#  'the',
#  'book',
#  'for',
#  'example',
#  'that',
#  'my',
#  'fondness',
#  'for',
#  'wodehouse',
#  'and',
#  'cricket',
#  'which',
#  'you',
#  'mentioned',
#  'actually',
#  'is',
#  'despite',
#  'in',
#  'many',
#  'ways',
#  'the',
#  'fact',
#  'that',
#  'they',
#  'have',
#  'english',
#  'origins',
#  'of',
#  'course',
#  'im',
#  'even',
#  'more',
#  'fond',
#  'of',
#  'cricket',
#  'now',
#  'that',
#  'we',
#  'regularly',
#  'beat',
#  'the',
#  'english',
#  'at',
#  'it',
#  'but',
#  'famously',
#  'an',
#  'indian',
#  'game',
#  'accidentally',
#  'discovered',
#  'by',
#  'the',
#  'british',
#  'i',
#  'think',
#  'thats',
#  'a',
#  'great',
#  'line',
#  'by',
#  'a',
#  'sociologist',
#  'called',
#  'ashish',
#  'nandy',
#  'that',
#  'its',
#  'actually',
#  'an',
#  'indian',
#  'game',
#  'accidentally',
#  'discovered',
#  'by',
#  'the',
#  'british',
#  'i',
#  'mean',
#  'clearly',
#  'our',
#  'climate',
#  'is',
#  'far',
#  'more',
#  'suitable',
#  'for',
#  'cricket',
#  'than',
#  'theirs',
#  'for',
#  'one',
#  'thing',
#  'but',
#  'anyway',
#  'where',
#  'were',
#  'we',
#  'ive',
#  'lost',
#  'my',
#  'train',
#  'of',
#  'thought',
#  'thats',
#  'okay',
#  'we',
#  'oh',
#  'yes',
#  'pg',
#  'wodehouse',
#  'for',
#  'example',
#  'obviously',
#  'the',
#  'delights',
#  'of',
#  'wodehouse',
#  'are',
#  'the',
#  'delights',
#  'that',
#  'are',
#  'imparted',
#  'to',
#  'you',
#  'by',
#  'your',
#  'appreciation',
#  'of',
#  'the',
#  'english',
#  'language',
#  'what',
#  'he',
#  'does',
#  'with',
#  'stylistic',
#  'humor',
#  'plotting',
#  'and',
#  'so',
#  'on',
#  'and',
#  'so',
#  'forth',
#  'but',
#  'the',
#  'interesting',
#  'thing',
#  'is',
#  'precisely',
#  'because',
#  'of',
#  'that',
#  'you',
#  'dont',
#  'actually',
#  'have',
#  'to',
#  'have',
#  'an',
#  'allegiance',
#  'to',
#  'britain',
#  'as',
#  'long',
#  'as',
#  'you',
#  'know',
#  'but',
#  'you',
#  'dont',
#  'need',
#  'the',
#  'passport',
#  'is',
#  'english',
#  'language',
#  'but',
#  'you',
#  'dont',
#  'need',
#  'a',
#  'british',
#  'visa',
#  'to',
#  'get',
#  'there',
#  'you',
#  'can',
#  'sit',
#  'in',
#  'india',
#  'surrounded',
#  'by',
#  'a',
#  'very',
#  'different',
#  'world',
#  'from',
#  'that',
#  'which',
#  'he',
#  'describes',
#  'and',
#  'enjoy',
#  'the',
#  'escapism',
#  'that',
#  'his',
#  'writing',
#  'represents',
#  'and',
#  'so',
#  'it',
#  'goes',
#  'but',
#  'i',
#  'realize',
#  'that',
#  'this',
#  'is',
#  'selfinterested',
#  'pleading',
#  'because',
#  'obviously',
#  'i',
#  'am',
#  'a',
#  'product',
#  'of',
#  'the',
#  'system',
#  'as',
#  'you',
#  'rightly',
#  'point',
#  'out',
#  'and',
#  'i',
#  'suppose',
#  'one',
#  'of',
#  'the',
#  'great',
#  'problems',
#  'with',
#  'history',
#  'is',
#  'you',
#  'cant',
#  'establish',
#  'the',
#  'counterfactual',
#  'its',
#  'impossible',
#  'to',
#  'know',
#  'what',
#  'india',
#  'might',
#  'look',
#  'like',
#  'had',
#  'the',
#  'british',
#  'not',
#  'been',
#  'there',
#  'can',
#  'i',
#  'take',
#  'you',
#  'to',
#  'those',
#  'more',
#  'structural',
#  'things',
#  'the',
#  'fact',
#  'that',
#  'india',
#  'speaks',
#  'the',
#  'world',
#  'language',
#  'the',
#  'fact',
#  'that',
#  'india',
#  'has',
#  'a',
#  'centralized',
#  'unitary',
#  'government',
#  'that',
#  'it',
#  'is',
#  'a',
#  'democracy',
#  'how',
#  'much',
#  'has',
#  'indias',
#  'way',
#  'in',
#  'the',
#  'world',
#  'being',
#  'made',
#  'easier',
#  'by',
#  'those',
#  'legacies',
#  'highly',
#  'contestant',
#  'no',
#  'theres',
#  'no',
#  'question',
#  'that',
#  'some',
#  'of',
#  'this',
#  'has',
#  'been',
#  'useful',
#  'to',
#  'us',
#  'and',
#  'the',
#  'english',
#  'language',
#  'certainly',
#  'but',
#  'i',
#  'want',
#  'to',
#  'stress',
#  'and',
#  'i',
#  'think',
#  'you',
#  'alluded',
#  'to',
#  'this',
#  'in',
#  'your',
#  'introduction',
#  'that',
#  'all',
#  'the',
#  'things',
#  'that',
#  'apologists',
#  'for',
#  'empire',
#  'like',
#  'to',
#  'claim',
#  'credit',
#  'for',
#  'the',
#  'english',
#  'language',
#  'parliamentary',
#  'democracy',
#  'the',
#  'rule',
#  'of',
#  'law',
#  'the',
#  'railways',
#  'you',
#  'know',
#  'all',
#  'of',
#  'the',
#  'classic',
#  'clichés',
#  'and',
#  'for',
#  'that',
#  'matter',
#  'even',
#  'tea',
#  'every',
#  'single',
#  'one',
#  'of',
#  'these',
#  'things',
#  'was',
#  'brought',
#  'in',
#  'by',
#  'the',
#  'british',
#  'to',
#  'advance',
#  'their',
#  'control',
#  'of',
#  'india',
#  'to',
#  'enhance',
#  'their',
#  'profits',
#  'and',
#  'serve',
#  'their',
#  'interests',
#  'not',
#  'one',
#  'was',
#  'intended',
#  'principally',
#  'to',
#  'benefit',
#  'indians',
#  'and',
#  'the',
#  'fact',
#  'that',
#  'when',
#  'they',
#  'left',
#  'they',
#  'couldnt',
#  'take',
#  'this',
#  'with',
#  'them',
#  'and',
#  'we',
#  'were',
#  'able',
#  'then',
#  'to',
#  'turn',
#  'them',
#  'around',
#  'to',
#  'purposes',
#  'the',
#  'original',
#  'people',
#  'who',
#  'introduced',
#  'them',
#  'would',
#  'never',
#  'have',
#  'intended',
#  'is',
#  'something',
#  'that',
#  'i',
#  'think',
#  'is',
#  'more',
#  'to',
#  'the',
#  'credit',
#  'of',
#  'the',
#  'indian',
#  'nationals',
#  'than',
#  'to',
#  'the',
#  'english',
#  'im',
#  'happy',
#  'to',
#  'go',
#  'through',
#  'the',
#  'examples',
#  'you',
#  'mentioned',
#  'you',
#  'take',
#  'language',
#  'for',
#  'example',
#  'the',
#  'british',
#  'had',
#  'no',
#  'intention',
#  'of',
#  'imparting',
#  'education',
#  'to',
#  'the',
#  'masses',
#  'of',
#  'indians',
#  'they',
#  'made',
#  'it',
#  'very',
#  'clear',
#  'they',
#  'werent',
#  'going',
#  'to',
#  'spend',
#  'the',
#  'money',
#  'doing',
#  'that',
#  'and',
#  'indeed',
#  'as',
#  'late',
#  'as',
#  'the',
#  'american',
#  'historian',
#  'will',
#  'durant',
#  'observed',
#  'that',
#  'the',
#  'entire',
#  'budgets',
#  'of',
#  'the',
#  'british',
#  'for',
#  'education',
#  'in',
#  'india',
#  'from',
#  'the',
#  'nursery',
#  'level',
#  'to',
#  'the',
#  'highest',
#  'university',
#  'levels',
#  'amounted',
#  'to',
#  'less',
#  'than',
#  'half',
#  'the',
#  'high',
#  'school',
#  'budget',
#  'of',
#  'the',
#  'state',
#  'of',
#  'new',
#  'york',
#  'and',
#  'that',
#  'was',
#  'for',
#  'the',
#  'entire',
#  'country',
#  'of',
#  'india',
#  'with',
#  'at',
#  'that',
#  'point',
#  'ten',
#  'times',
#  'as',
#  'many',
#  'people',
#  'as',
#  'the',
#  'state',
#  'of',
#  'new',
#  'york',
#  'the',
#  'fact',
#  'is',
#  'that',
#  'the',
#  'british',
#  'were',
#  'not',
#  'interested',
#  'in',
#  'investing',
#  'in',
#  'education',
#  'and',
#  'even',
#  'the',
#  'english',
#  'language',
#  'was',
#  'brought',
#  'in',
#  'just',
#  'to',
#  'educate',
#  'a',
#  'narrow',
#  'class',
#  'of',
#  'interpreters',
#  'between',
#  'the',
#  'governors',
#  'and',
#  'the',
#  'governed',
#  'people',
#  'who',
#  'would',
#  'help',
#  'the',
#  'british',
#  'by',
#  'constituting',
#  'a',
#  'buffer',
#  'between',
#  'them',
#  'and',
#  'the',
#  'dirty',
#  'masses',
#  'on',
#  'their',
#  'rule',
#  'i',
#  'mean',
#  'that',
#  'was',
#  'very',
#  'much',
#  'the',
#  'actual',
#  'macaulay',
#  'actually',
#  'said',
#  'this',
#  'in',
#  'his',
#  'notorious',
#  'minute',
#  'on',
#  'education',
#  'and',
#  'he',
#  'said',
#  'that',
#  'we',
#  'need',
#  'to',
#  'create',
#  'a',
#  'class',
#  'of',
#  'indians',
#  'indian',
#  'in',
#  'skin',
#  'and',
#  'color',
#  'but',
#  'english',
#  'in',
#  'opinions',
#  'and',
#  'tastes',
#  'and',
#  'morals',
#  'and',
#  'in',
#  'intellect',
#  'those',
#  'were',
#  'his',
#  'exact',
#  'words',
#  'and',
#  'it',
#  'was',
#  'to',
#  'serve',
#  'their',
#  'purposes',
#  'now',
#  'of',
#  'course',
#  'indians',
#  'then',
#  'used',
#  'english',
#  'to',
#  'open',
#  'up',
#  'on',
#  'another',
#  'world',
#  'of',
#  'ideas',
#  'often',
#  'very',
#  'radical',
#  'and',
#  'critical',
#  'ideas',
#  'and',
#  'ideas',
#  'that',
#  'eventually',
#  'made',
#  'english',
#  'a',
#  'language',
#  'of',
#  'indian',
#  'nationalism',
#  'our',
#  'first',
#  'prime',
#  'minister',
#  'jawaharlal',
#  'nehru',
#  'wrote',
#  'his',
#  'classic',
#  'the',
#  'discovery',
#  'of',
#  'india',
#  'in',
#  'english',
#  'so',
#  'the',
#  'indian',
#  'nationalist',
#  'discovered',
#  'india',
#  'in',
#  'english',
#  'as',
#  'it',
#  'were',
#  'but',
#  'that',
#  'was',
#  'our',
#  'if',
#  'you',
#  'like',
#  'change',
#  'of',
#  'what',
#  'the',
#  'british',
#  'had',
#  'intended',
#  'to',
#  'do',
#  'democracy',
#  'and',
#  'you',
#  'mentioned',
#  'political',
#  'unity',
#  'well',
#  'political',
#  'unity',
#  'is',
#  'the',
#  'one',
#  'that',
#  'the',
#  'british',
#  'point',
#  'to',
#  'with',
#  'pride',
#  'that',
#  'they',
#  'came',
#  'into',
#  'a',
#  'bunch',
#  'of',
#  'warring',
#  'principalities',
#  'and',
#  'they',
#  'made',
#  'a',
#  'country',
#  'out',
#  'of',
#  'it',
#  'not',
#  'so',
#  'for',
#  'years',
#  'before',
#  'the',
#  'british',
#  'ever',
#  'set',
#  'foot',
#  'on',
#  'india',
#  'there',
#  'have',
#  'been',
#  'a',
#  'very',
#  'clear',
#  'sense',
#  'of',
#  'a',
#  'common',
#  'civilizational',
#  'unity',
#  'and',
#  'an',
#  'aspiration',
#  'on',
#  'the',
#  'part',
#  'of',
#  'monarchs',
#  'to',
#  'consolidate',
#  'that',
#  'territorially',
#  'now',
#  'obviously',
#  'they',
#  'couldnt',
#  'i',
#  'mean',
#  'we',
#  'had',
#  'two',
#  'people',
#  'who',
#  'came',
#  'very',
#  'close',
#  'there',
#  'was',
#  'the',
#  'mauryan',
#  'empire',
#  'ashoka',
#  'and',
#  'chandragupta',
#  'who',
#  'controlled',
#  'about',
#  'of',
#  'the',
#  'subcontinent',
#  'including',
#  'afghanistan',
#  'and',
#  'then',
#  'the',
#  'mughals',
#  'particularly',
#  'akbar',
#  'and',
#  'aurangzeb',
#  'they',
#  'controlled',
#  'about',
#  'of',
#  'the',
#  'subcontinent',
#  'and',
#  'that',
#  'was',
#  'the',
#  'extent',
#  'but',
#  'the',
#  'fact',
#  'that',
#  'everyone',
#  'tried',
#  'to',
#  'do',
#  'it',
#  'aspired',
#  'to',
#  'do',
#  'it',
#  'and',
#  'failed',
#  'in',
#  'trying',
#  'shows',
#  'that',
#  'if',
#  'the',
#  'british',
#  'hadnt',
#  'succeeded',
#  'somebody',
#  'else',
#  'around',
#  'the',
#  'same',
#  'time',
#  ...]

# %% [markdown]
# ###Freqency analysis

# %% [markdown]
# ####Calculating frequencies

# %%
t1freq = freq(t1tokens)
print(t1freq)
# Out:
# {'madam': 4, 'president': 3, 'and': 54, 'gentlemen': 1, 'ladies': 1, 'of': 97, 'the': 145, 'house': 3, 'i': 33, 'standing': 1, 'here': 3, 'with': 10, 'eight': 2, 'minutes': 1, 'in': 48, 'my': 3, 'hands': 1, 'this': 11, 'venerable': 1, 'rather': 3, 'magnificent': 1, 'institution': 1, 'was': 32, 'going': 2, 'to': 67, 'assure': 1, 'you': 18, 'that': 59, 'belong': 1, 'henry': 3, 'viii': 2, 'school': 1, 'public': 3, 'speaking': 2, 'as': 29, 'said': 5, 'his': 4, 'wives': 1, 'shall': 1, 'not': 16, 'keep': 1, 'long': 2, 'but': 13, 'now': 5, 'finding': 1, 'myself': 1, 'seventh': 1, 'speaker': 3, 'out': 18, 'what': 9, 'must': 1, 'already': 2, 'seem': 1, 'a': 19, 'evening': 1, 'feel': 1, 'like': 3, 'viiis': 1, 'last': 3, 'wife': 1, 'more': 2, 'or': 8, 'less': 3, 'know': 2, 'whats': 1, 'expected': 1, 'me': 9, 'am': 11, 'sure': 1, 'how': 3, 'do': 4, 'it': 17, 'any': 1, 'differently': 1, 'perhaps': 2, 'should': 2, 'is': 28, 'really': 4, 'try': 2, 'pay': 1, 'attention': 1, 'arguments': 4, 'have': 11, 'advanced': 1, 'by': 12, 'opposition': 2, 'today': 1, 'we': 8, 'had': 15, 'for': 17, 'example': 7, 'sir': 3, 'richard': 3, 'ottaway': 2, 'suggesting': 1, 'challenging': 1, 'very': 5, 'idea': 1, 'could': 1, 'be': 13, 'argued': 1, 'economic': 1, 'situation': 1, 'colonies': 2, 'actually': 9, 'worsened': 1, 'experience': 3, 'british': 18, 'colonialism': 5, 'well': 9, 'stand': 1, 'offer': 1, 'indian': 10, 'india': 25, 'share': 1, 'world': 9, 'economy': 2, 'when': 6, 'britain': 11, 'arrived': 1, 'on': 11, 'its': 5, 'shores': 1, 'time': 3, 'left': 1, 'down': 1, 'below': 1, 'why': 2, 'simply': 4, 'because': 6, 'been': 9, 'governed': 1, 'benefit': 1, 'britains': 5, 'rise': 1, 'years': 5, 'financed': 1, 'depredations': 1, 'fact': 11, 'industrial': 1, 'revolution': 1, 'premised': 1, 'upon': 1, 'deindustrialization': 1, 'handloom': 1, 'weavers': 3, 'famed': 1, 'across': 2, 'whose': 1, 'products': 3, 'were': 15, 'exported': 1, 'around': 1, 'came': 4, 'right': 4, 'there': 17, 'these': 5, 'making': 1, 'fine': 2, 'muslin': 1, 'light': 2, 'woven': 1, 'wear': 1, 'smashed': 1, 'their': 17, 'thumbs': 1, 'broke': 1, 'looms': 1, 'imposed': 1, 'tariffs': 1, 'duties': 1, 'cloth': 3, 'started': 1, 'course': 4, 'taking': 2, 'raw': 2, 'materials': 2, 'from': 15, 'shipping': 1, 'back': 1, 'manufactured': 1, 'flooding': 1, 'worlds': 2, 'markets': 1, 'became': 2, 'dark': 2, 'satanic': 1, 'mills': 1, 'victoria': 1, 'england': 2, 'meant': 1, 'beggars': 1, 'went': 1, 'being': 2, 'famous': 2, 'exporter': 1, 'finished': 1, 'into': 5, 'an': 7, 'importer': 1, 'having': 2, 'trade': 1, 'than': 3, 'meanwhile': 1, 'colonialists': 1, 'robert': 1, 'clive': 2, 'bought': 1, 'rotten': 1, 'boroughs': 1, 'proceeds': 1, 'loot': 3, 'while': 2, 'hindi': 1, 'word': 1, 'dictionary': 1, 'habits': 1, 'gall': 1, 'call': 1, 'him': 3, 'if': 6, 'he': 5, 'belonged': 2, 'country': 2, 'all': 13, 'did': 1, 'ensure': 1, 'much': 5, 'end': 3, 'th': 2, 'century': 2, 'biggest': 2, 'cash': 1, 'cow': 1, 'purchaser': 1, 'goods': 1, 'exports': 1, 'source': 1, 'highly': 1, 'paid': 10, 'employment': 2, 'civil': 1, 'servants': 1, 'literally': 1, 'our': 3, 'own': 1, 'oppression': 1, 'has': 7, 'pointed': 6, 'wealthy': 2, 'victorian': 1, 'families': 1, 'made': 4, 'money': 8, 'slave': 1, 'one': 7, 'fifth': 1, 'elites': 1, 'class': 1, 'owed': 4, 'transporting': 1, 'million': 11, 'africans': 2, 'waters': 1, 'slavery': 2, 'abolished': 1, 'happened': 1, 'compensation': 2, 'pounds': 4, 'reparations': 12, 'those': 4, 'who': 4, 'lost': 3, 'lives': 2, 'suffered': 2, 'oppressed': 1, 'property': 2, 'struck': 1, 'your': 4, 'wifi': 1, 'password': 1, 'at': 4, 'union': 3, 'commemorates': 1, 'name': 1, 'mr': 5, 'gladstone': 1, 'great': 2, 'liberal': 1, 'hero': 1, 'sorry': 9, 'family': 1, 'benefited': 1, 'staying': 1, 'between': 1, 'indians': 4, 'died': 3, 'starvation': 2, 'induced': 1, 'famines': 1, 'most': 1, 'bengal': 2, 'famine': 1, 'during': 1, 'war': 8, 'ii': 2, 'people': 9, 'winston': 1, 'churchill': 1, 'deliberately': 1, 'matter': ...

# %%
t2freq = freq(t2tokens)
print(t2freq)
# Out:
# {'one': 19, 'of': 144, 'the': 292, 'more': 9, 'insidious': 1, 'challenges': 1, 'colonialism': 2, 'is': 44, 'extent': 4, 'to': 112, 'which': 18, 'our': 4, 'minds': 1, 'are': 23, 'colonized': 1, 'as': 31, 'well': 9, 'and': 118, 'that': 85, 'colonization': 1, 'a': 76, 'mind': 1, 'takes': 1, 'some': 4, 'growing': 1, 'out': 14, 'for': 36, 'us': 4, 'never': 4, 'really': 5, 'grow': 1, 'it': 46, 'i': 32, 'mean': 6, 'do': 11, 'know': 7, 'there': 23, 'many': 5, 'who': 16, 'cant': 5, 'help': 4, 'were': 20, 'identification': 1, 'with': 19, 'things': 6, 'anglophone': 1, 'anglophile': 2, 'because': 14, 'thats': 6, 'what': 16, 'they': 39, 'schooled': 1, 'appreciate': 1, 'have': 17, 'argued': 1, 'in': 83, 'book': 5, 'example': 8, 'my': 4, 'fondness': 1, 'wodehouse': 3, 'cricket': 3, 'you': 30, 'mentioned': 4, 'actually': 9, 'despite': 1, 'ways': 1, 'fact': 12, 'english': 16, 'origins': 1, 'course': 4, 'im': 2, 'even': 15, 'fond': 1, 'now': 7, 'we': 11, 'regularly': 1, 'beat': 1, 'at': 19, 'but': 32, 'famously': 1, 'an': 15, 'indian': 12, 'game': 2, 'accidentally': 2, 'discovered': 3, 'by': 18, 'british': 47, 'think': 6, 'great': 5, 'line': 2, 'sociologist': 1, 'called': 3, 'ashish': 1, 'nandy': 1, 'its': 7, 'clearly': 1, 'climate': 1, 'far': 2, 'suitable': 1, 'than': 4, 'theirs': 1, 'thing': 9, 'anyway': 2, 'where': 3, 'ive': 6, 'lost': 1, 'train': 1, 'thought': 1, 'okay': 1, 'oh': 2, 'yes': 1, 'pg': 1, 'obviously': 3, 'delights': 2, 'imparted': 1, 'your': 4, 'appreciation': 1, 'language': 8, 'he': 23, 'does': 1, 'stylistic': 1, 'humor': 1, 'plotting': 1, 'so': 30, 'on': 28, 'forth': 2, 'interesting': 1, 'precisely': 1, 'dont': 5, 'allegiance': 1, 'britain': 7, 'long': 3, 'need': 4, 'passport': 1, 'visa': 1, 'get': 2, 'can': 7, 'sit': 1, 'india': 23, 'surrounded': 1, 'very': 13, 'different': 1, 'world': 10, 'from': 9, 'describes': 1, 'enjoy': 1, 'escapism': 1, 'his': 10, 'writing': 1, 'represents': 1, 'goes': 1, 'realize': 1, 'this': 24, 'selfinterested': 1, 'pleading': 1, 'am': 1, 'product': 1, 'system': 2, 'rightly': 1, 'point': 5, 'suppose': 1, 'problems': 1, 'history': 5, 'establish': 1, 'counterfactual': 1, 'impossible': 1, 'might': 1, 'look': 4, 'like': 5, 'had': 19, 'not': 25, 'been': 8, 'take': 7, 'those': 7, 'structural': 1, 'speaks': 1, 'has': 5, 'centralized': 1, 'unitary': 1, 'government': 5, 'democracy': 8, 'how': 5, 'much': 7, 'indias': 1, 'way': 5, 'being': 4, 'made': 4, 'easier': 2, 'legacies': 1, 'highly': 1, 'contestant': 1, 'no': 13, 'theres': 8, 'question': 1, 'useful': 1, 'certainly': 1, 'want': 2, 'stress': 1, 'alluded': 1, 'introduction': 1, 'all': 17, 'apologists': 1, 'empire': 4, 'claim': 2, 'credit': 2, 'parliamentary': 1, 'rule': 4, 'law': 2, 'railways': 1, 'classic': 2, 'clichés': 1, 'matter': 2, 'tea': 1, 'every': 3, 'single': 3, 'these': 6, 'was': 46, 'brought': 2, 'advance': 1, 'their': 18, 'control': 1, 'enhance': 2, 'profits': 1, 'serve': 2, 'interests': 2, 'intended': 3, 'principally': 1, 'benefit': 1, 'indians': 18, 'when': 6, 'left': 2, 'couldnt': 4, 'them': 10, 'able': 1, 'then': 7, 'turn': 1, 'around': 2, 'purposes': 2, 'original': 1, 'people': 27, 'introduced': 1, 'would': 12, 'something': 1, 'nationals': 1, 'happy': 1, 'go': 6, 'through': 1, 'examples': 1, 'intention': 3, 'imparting': 1, 'education': 4, 'masses': 2, 'clear': 2, 'werent': 1, 'going': 2, 'spend': 2, 'money': 5, 'doing': 2, 'indeed': 2, 'late': 2, 'american': 1, 'historian': 1, 'will': 4, 'durant': 1, 'observed': 1, 'entire': 4, 'budgets': 1, 'nursery': 1, 'level': 1, 'highest': 1, 'university': 1, 'levels': 1, 'amounted': 1, 'less': 3, 'half': 2, 'high': 1, 'school': 1, 'budget': 1, 'state': 3, 'new': 2, 'york': 2, 'country': 2, 'ten': 1, 'times': 2, 'interested': 1, 'investing': 1, 'just': 5, 'educate': 1, 'narrow': 2, 'class': 2, 'interpreters': 1, 'between': 2, 'governors': 1, 'governed': 1, 'constituting': 1, 'buffer': 2, 'dirty': 1, 'actual': 1, 'macaulay': 1, 'said': 7, 'notorious': 1, 'minute': 1, 'create': 1, 'skin': 1, 'color': 1 ...

# %% [markdown]
# ####Frequency graph of most frequent 60 words

# %%
t1freq_graph = freq_graph(t1tokens)

# %%
t2freq_graph = freq_graph(t2tokens)

# %% [markdown]
# Generating word cloud without removing stopwords

# %%
t1wordcloud = word_cloud(t1freq)
showCloud(t1wordcloud)

# %%
t2wordcloud = word_cloud(t2freq)
showCloud(t2wordcloud)

# %% [markdown]
# ###Generating wordcloud without stopwords

# %% [markdown]
# ####Removing stopwords

# %%
t1nostoptokens = stopwords_text(t1)

# %%
t2nostoptokens = stopwords_text(t2)

# %% [markdown]
# ####Frequency graph of most frequent 60 words after removing stopwords
#
# ---

# %%
t1nostopfreq = freq(t1nostoptokens)
t1nostopfreq_graph = freq_graph(t1nostoptokens)

# %%
t2nostopfreq = freq(t2nostoptokens)
t2nostopfreq_graph = freq_graph(t2nostoptokens)

# %% [markdown]
# ####Wordcloud after removing stopwords

# %%
t1nostopwordcloud = word_cloud(t1nostopfreq)
showCloud(t1nostopwordcloud)

# %%
t2nostopwordcloud = word_cloud(t2nostopfreq)
showCloud(t2nostopwordcloud)

# %% [markdown]
# #Frequency relation with length of words

# %%
word_counter(t1)

list_count_t1 = sorted(words.items())
x1, y1 = zip(*list_count_t1)
plt.plot(x1, y1)
plt.xticks(range(0, 30))
plt.rcParams["figure.figsize"] = (15, 10)
plt.xlabel("Wordlength")
plt.ylabel("Frequency")
plt.show()

# %%
list_count_t2 = sorted(words.items())
x2, y2 = zip(*list_count_t2)
plt.plot(x2, y2)
plt.xticks(range(0, 30))
plt.rcParams["figure.figsize"] = (15, 10)
plt.xlabel("Wordlength")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #POS Tagging the contents of textbook

# %% [markdown]
# ###Tagging words

# %%
tagged1 = nltk.pos_tag(t1tokens)
tagged1
# Out:
# [('madam', 'NN'),
#  ('president', 'NN'),
#  ('and', 'CC'),
#  ('gentlemen', 'JJ'),
#  ('ladies', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('house', 'NN'),
#  ('i', 'NN'),
#  ('standing', 'VBG'),
#  ('here', 'RB'),
#  ('with', 'IN'),
#  ('eight', 'CD'),
#  ('minutes', 'NNS'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('hands', 'NNS'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('venerable', 'JJ'),
#  ('and', 'CC'),
#  ('rather', 'RB'),
#  ('magnificent', 'JJ'),
#  ('institution', 'NN'),
#  ('i', 'NN'),
#  ('was', 'VBD'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('assure', 'VB'),
#  ('you', 'PRP'),
#  ('that', 'IN'),
#  ('i', 'VBZ'),
#  ('belong', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('henry', 'NN'),
#  ('viii', 'JJ'),
#  ('school', 'NN'),
#  ('of', 'IN'),
#  ('public', 'JJ'),
#  ('speaking', 'NN'),
#  ('that', 'IN'),
#  ('as', 'IN'),
#  ('henry', 'NN'),
#  ('viii', 'NN'),
#  ('said', 'VBD'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('wives', 'NNS'),
#  ('i', 'VBP'),
#  ('shall', 'MD'),
#  ('not', 'RB'),
#  ('keep', 'VB'),
#  ('you', 'PRP'),
#  ('long', 'JJ'),
#  ('but', 'CC'),
#  ('now', 'RB'),
#  ('finding', 'VBG'),
#  ('myself', 'PRP'),
#  ('the', 'DT'),
#  ('seventh', 'JJ'),
#  ('speaker', 'NN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('eight', 'CD'),
#  ('in', 'IN'),
#  ('what', 'WP'),
#  ('must', 'MD'),
#  ('already', 'RB'),
#  ('seem', 'VB'),
#  ('a', 'DT'),
#  ('rather', 'RB'),
#  ('long', 'JJ'),
#  ('evening', 'NN'),
#  ('to', 'TO'),
#  ('you', 'PRP'),
#  ('i', 'VBP'),
#  ('rather', 'RB'),
#  ('feel', 'VBP'),
#  ('like', 'IN'),
#  ('henry', 'NN'),
#  ('viiis', 'VBP'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('wife', 'NN'),
#  ('i', 'VBD'),
#  ('more', 'RBR'),
#  ('or', 'CC'),
#  ('less', 'RBR'),
#  ('know', 'JJ'),
#  ('whats', 'NNS'),
#  ('expected', 'VBN'),
#  ('of', 'IN'),
#  ('me', 'PRP'),
#  ('but', 'CC'),
#  ('i', 'VB'),
#  ('am', 'VBP'),
#  ('not', 'RB'),
#  ('sure', 'JJ'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('it', 'PRP'),
#  ('any', 'DT'),
#  ('differently', 'RB'),
#  ('perhaps', 'RB'),
#  ('what', 'WP'),
#  ('i', 'NN'),
#  ('should', 'MD'),
#  ('do', 'VB'),
#  ('is', 'VBZ'),
#  ('really', 'RB'),
#  ('try', 'JJ'),
#  ('and', 'CC'),
#  ('pay', 'VB'),
#  ('attention', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('arguments', 'NNS'),
#  ('that', 'WDT'),
#  ('have', 'VBP'),
#  ('advanced', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('opposition', 'NN'),
#  ('today', 'NN'),
#  ('we', 'PRP'),
#  ('had', 'VBD'),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  ('sir', 'JJ'),
#  ('richard', 'NN'),
#  ('ottaway', 'NN'),
#  ('suggesting', 'VBG'),
#  ('challenging', 'VBG'),
#  ('the', 'DT'),
#  ('very', 'RB'),
#  ('idea', 'NN'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('could', 'MD'),
#  ('be', 'VB'),
#  ('argued', 'VBN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('economic', 'JJ'),
#  ('situation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('colonies', 'NNS'),
#  ('was', 'VBD'),
#  ('actually', 'RB'),
#  ('worsened', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('experience', 'NN'),
#  ('of', 'IN'),
#  ('british', 'JJ'),
#  ('colonialism', 'NN'),
#  ('well', 'RB'),
#  ('i', 'RB'),
#  ('stand', 'VBP'),
#  ('to', 'TO'),
#  ('offer', 'VB'),
#  ('you', 'PRP'),
#  ('the', 'DT'),
#  ('indian', 'JJ'),
#  ('example', 'NN'),
#  ('sir', 'JJ'),
#  ('richard', 'NN'),
#  ('india', 'NN'),
#  ('share', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('economy', 'NN'),
#  ('when', 'WRB'),
#  ('britain', 'NN'),
#  ('arrived', 'VBD'),
#  ('on', 'IN'),
#  ('its', 'PRP$'),
#  ('shores', 'NNS'),
#  ('was', 'VBD'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('left', 'VBD'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('down', 'RB'),
#  ('to', 'TO'),
#  ('below', 'VB'),
#  ('why', 'WRB'),
#  ('simply', 'RB'),
#  ('because', 'IN'),
#  ('india', 'NN'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('governed', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('benefit', 'NN'),
#  ('of', 'IN'),
#  ('britain', 'NN'),
#  ('britains', 'NNS'),
#  ('rise', 'VBP'),
#  ('for', 'IN'),
#  ('years', 'NNS'),
#  ('was', 'VBD'),
#  ('financed', 'VBN'),
#  ('by', 'IN'),
#  ('its', 'PRP$'),
#  ('depredations', 'NNS'),
#  ('in', 'IN'),
#  ('india', 'NN'),
#  ('in', 'IN'),
#  ('fact', 'NN'),
#  ('britains', 'NNS'),
#  ('industrial', 'JJ'),
#  ('revolution', 'NN'),
#  ('was', 'VBD'),
#  ('actually', 'RB'),
#  ('premised', 'VBN'),
#  ('upon', 'IN'),
#  ('the', 'DT'),
#  ('deindustrialization', 'NN'),
#  ('of', 'IN'),
#  ('india', 'NN'),
#  ('the', 'DT'),
#  ('handloom', 'NN'),
#  ('weavers', 'NNS'),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  ('famed', 'VBN'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('whose', 'WP$'),
#  ('products', 'NNS'),
#  ('were', 'VBD'),
#  ('exported', 'VBN'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('britain', 'NN'),
#  ('came', 'VBD'),
#  ('right', 'RB'),
#  ('in', 'IN'),
#  ('there', 'EX'),
#  ('were', 'VBD'),
#  ('actually', 'RB'),
#  ('these', 'DT'),
#  ('weavers', 'NNS'),
#  ('making', 'VBG'),
#  ('fine', 'JJ'),
#  ('muslin', 'NN'),
#  ('as', 'RB'),
#  ('light', 'JJ'),
#  ('as', 'IN'),
#  ('woven', 'JJ'),
#  ('wear', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('said', 'VBD'),
#  ('and', 'CC'),
#  ('britain', 'NN'),
#  ('came', 'VBD'),
#  ('right', 'RB'),
#  ('in', 'IN'),
#  ('smashed', 'VBN'),
#  ('their', 'PRP$'),
#  ('thumbs', 'NNS'),
#  ('broke', 'VBD'),
#  ('their', 'PRP$'),
#  ('looms', 'NNS'),
#  ('imposed', 'VBN'),
#  ('tariffs', 'NNS'),
#  ('and', 'CC'),
#  ('duties', 'NNS'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('cloth', 'NN'),
#  ('and', 'CC'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('started', 'VBD'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('taking', 'VBG'),
#  ('the', 'DT'),
#  ('raw', 'JJ'),
#  ('materials', 'NNS'),
#  ('from', 'IN'),
#  ('india', 'NN'),
#  ('and', 'CC'),
#  ('shipping', 'NN'),
#  ('back', 'RB'),
#  ('manufactured', 'VBD'),
#  ('cloth', 'NN'),
#  ('flooding', 'VBG'),
#  ('the', 'DT'),
#  ('worlds', 'NNS'),
#  ('markets', 'NNS'),
#  ('with', 'IN'),
#  ('what', 'WP'),
#  ('became', 'VBD'),
#  ('the', 'DT'),
#  ('products', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('dark', 'NN'),
#  ('and', 'CC'),
#  ('satanic', 'JJ'),
#  ('mills', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('victoria', 'NN'),
#  ('in', 'IN'),
#  ('england', 'NN'),
#  ('that', 'WDT'),
#  ('meant', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('weavers', 'NNS'),
#  ('in', 'IN'),
#  ('india', 'NN'),
#  ('became', 'VBD'),
#  ('beggars', 'NNS'),
#  ('and', 'CC'),
#  ('india', 'VB'),
#  ('went', 'VBD'),
#  ('from', 'IN'),
#  ('being', 'VBG'),
#  ('a', 'DT'),
#  ('world', 'NN'),
#  ('famous', 'JJ'),
#  ('exporter', 'NN'),
#  ('of', 'IN'),
#  ('finished', 'JJ'),
#  ('cloth', 'NN'),
#  ('into', 'IN'),
#  ('an', 'DT'),
#  ('importer', 'NN'),
#  ('when', 'WRB'),
#  ('from', 'IN'),
#  ('having', 'VBG'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('trade', 'NN'),
#  ('to', 'TO'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('meanwhile', 'RB'),
#  ('colonialists', 'NNS'),
#  ('like', 'IN'),
#  ('robert', 'NN'),
#  ('clive', 'JJ'),
#  ('bought', 'VBD'),
#  ('their', 'PRP$'),
#  ('rotten', 'JJ'),
#  ('boroughs', 'NNS'),
#  ('in', 'IN'),
#  ('england', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('proceeds', 'NNS'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('loot', 'NN'),
#  ('in', 'IN'),
#  ('india', 'NN'),
#  ('while', 'IN'),
#  ('taking', 'VBG'),
#  ('the', 'DT'),
#  ('hindi', 'NN'),
#  ('word', 'NN'),
#  ('loot', 'NN'),
#  ('into', 'IN'),
#  ('their', 'PRP$'),
#  ('dictionary', 'JJ'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('their', 'PRP$'),
#  ('habits', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('had', 'VBD'),
#  ('the', 'DT'),
#  ('gall', 'NN'),
#  ('to', 'TO'),
#  ('call', 'VB'),
#  ('him', 'PRP'),
#  ('clive', 'JJ'),
#  ('of', 'IN'),
#  ('india', 'NN'),
#  ('as', 'IN'),
#  ('if', 'IN'),
#  ('he', 'PRP'),
#  ('belonged', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('when', 'WRB'),
#  ('all', 'DT'),
#  ('he', 'PRP'),
#  ('really', 'RB'),
#  ('did', 'VBD'),
#  ('was', 'VBD'),
#  ('to', 'TO'),
#  ('ensure', 'VB'),
#  ('that', 'IN'),
#  ('much', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('belonged', 'VBD'),
#  ('to', 'TO'),
#  ('him', 'PRP'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('th', 'JJ'),
#  ('century', 'NN'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('india', 'NN'),
#  ('was', 'VBD'),
#  ('already', 'RB'),
#  ('britains', 'VBZ'),
#  ('biggest', 'JJS'),
#  ('cash', 'NN'),
#  ('cow', 'VBD'),
#  ('the', 'DT'),
#  ('worlds', 'NNS'),
#  ('biggest', 'JJS'),
#  ('purchaser', 'NN'),
#  ('of', 'IN'),
#  ('british', 'JJ'),
#  ('goods', 'NNS'),
#  ('and', 'CC'),
#  ('exports', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('source', 'NN'),
#  ('for', 'IN'),
#  ('highly', 'RB'),
#  ('paid', 'VBN'),
#  ('employment', 'NN'),
#  ('for', 'IN'),
#  ('british', 'JJ'),
#  ('civil', 'JJ'),
#  ('servants', 'NNS'),
#  ('we', 'PRP'),
#  ('literally', 'RB'),
#  ('paid', 'VBD'),
#  ('for', 'IN'),
#  ('our', 'PRP$'),
#  ('own', 'JJ'),
#  ('oppression', 'NN'),
#  ('and', 'CC'),
#  ('as', 'IN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('pointed', 'VBN'),
#  ('out', 'RP'),
#  ('the', 'DT'),
#  ('wealthy', 'JJ'),
#  ('victorian', 'JJ'),
#  ('british', 'JJ'),
#  ('families', 'NNS'),
#  ('that', 'WDT'),
#  ('made', 'VBD'),
#  ('their', 'PRP$'),
#  ('money', 'NN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('slave', 'JJ'),
#  ('economy', 'NN'),
#  ('one', 'CD'),
#  ('fifth', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('elites', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('wealthy', 'JJ'),
#  ('class', 'NN'),
#  ('in', 'IN'),
#  ('britain', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('th', 'JJ'),
#  ('century', 'NN'),
#  ('owed', 'VBD'),
#  ('their', 'PRP$'),
#  ('money', 'NN'),
#  ('to', 'TO'),
#  ('transporting', 'VBG'),
#  ('million', 'CD'),
#  ('africans', 'NNS'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('waters', 'NNS'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('fact', 'NN'),
#  ('in', 'IN'),
#  ('when', 'WRB'),
#  ('slavery', 'NN'),
#  ('was', 'VBD'),
#  ('abolished', 'VBN'),
#  ('and', 'CC'),
#  ('what', 'WP'),
#  ('happened', 'VBD'),
#  ('was', 'VBD'),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('compensation', 'NN'),
#  ('of', 'IN'),
#  ('million', 'CD'),
#  ('pounds', 'NNS'),
#  ('was', 'VBD'),
#  ('paid', 'VBN'),
#  ('not', 'RB'),
#  ('as', 'IN'),
#  ('reparations', 'NNS'),
#  ('to', 'TO'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('lost', 'VBN'),
#  ('their', 'PRP$'),
#  ('lives', 'NNS'),
#  ('or', 'CC'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('suffered', 'VBN'),
#  ('or', 'CC'),
#  ('been', 'VBN'),
#  ('oppressed', 'VBN'),
#  ('by', 'IN'),
#  ('slavery', 'NN'),
#  ('but', 'CC'),
#  ('to', 'TO'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('lost', 'VBN'),
#  ('their', 'PRP$'),
#  ('property', 'NN'),
#  ('i', 'NN'),
#  ('was', 'VBD'),
#  ('struck', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('your', 'PRP$'),
#  ('wifi', 'NN'),
#  ('password', 'NN'),
#  ('at', 'IN'),
#  ('this', 'DT'),
#  ('union', 'NN'),
#  ('commemorates', 'VBZ'),
#  ('the', 'DT'),
#  ('name', 'NN'),
#  ('of', 'IN'),
#  ('mr', 'NN'),
#  ('gladstone', 'NN'),
#  ('the', 'DT'),
#  ('great', 'JJ'),
#  ('liberal', 'JJ'),
#  ('hero', 'NN'),
#  ('well', 'RB'),
#  ('i', 'RB'),
#  ('am', 'VBP'),
#  ('very', 'RB'),
#  ('sorry', 'JJ'),
#  ('his', 'PRP$'),
#  ('family', 'NN'),
#  ('was', 'VBD'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('benefited', 'VBD'),
#  ('from', 'IN'),
#  ('this', 'DT'),
#  ('compensation', 'NN'),
#  ('staying', 'VBG'),
#  ('with', 'IN'),
#  ('india', 'NN'),
#  ('between', 'IN'),
#  ('million', 'CD'),
#  ('and', 'CC'),
#  ('million', 'CD'),
#  ('indians', 'NNS'),
#  ('died', 'VBN'),
#  ('of', 'IN'),
#  ('starvation', 'NN'),
#  ('in', 'IN'),
#  ('british', 'JJ'),
#  ('induced', 'JJ'),
#  ('famines', 'NNS'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('famous', 'JJ'),
#  ('example', 'NN'),
#  ('was', 'VBD'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('great', 'JJ'),
#  ('bengal', 'JJ'),
#  ('famine', 'NN'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('ii', 'NN'),
#  ('when', 'WRB'),
#  ('million', 'CD'),
#  ('people', 'NNS'),
#  ('died', 'VBD'),
#  ('because', 'IN'),
#  ('winston', 'NN'),
#  ('churchill', 'NN'),
#  ('deliberately', 'RB'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('matter', 'NN'),
#  ('of', 'IN'),
#  ('written', 'VBN'),
#  ('policy', 'NN'),
#  ('proceeded', 'VBN'),
#  ('to', 'TO'),
#  ('divert', 'VB'),
#  ('essential', 'JJ'),
#  ('supplies', 'NNS'),
#  ('from', 'IN'),
#  ('civilians', 'NNS'),
#  ('in', 'IN'),
#  ('bengal', 'NN'),
#  ('to', 'TO'),
#  ('sturdy', 'VB'),
#  ('tummies', 'NNS'),
#  ('and', 'CC'),
#  ('europeans', 'NNS'),
#  ('as', 'IN'),
#  ('reserve', 'NN'),
#  ('stockpiles', 'NNS'),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('starvation', 'NN'),
#  ('of', 'IN'),
#  ('anyway', 'RB'),
#  ('underfed', 'JJ'),
#  ('bengalis', 'NN'),
#  ('mattered', 'VBD'),
#  ('much', 'RB'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('that', 'DT'),
#  ('of', 'IN'),
#  ('sturdy', 'JJ'),
#  ('greeks', 'NN'),
#  ('churchills', 'NNS'),
#  ('actual', 'JJ'),
#  ('quote', 'NN'),
#  ('and', 'CC'),
#  ('when', 'WRB'),
#  ('conscious', 'JJ'),
#  ('stricken', 'JJ'),
#  ('british', 'JJ'),
#  ('officials', 'NNS'),
#  ('wrote', 'VBD'),
#  ('to', 'TO'),
#  ('him', 'PRP'),
#  ('pointing', 'VBG'),
#  ('out', 'RP'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('were', 'VBD'),
#  ('dying', 'VBG'),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('decision', 'NN'),
#  ('he', 'PRP'),
#  ('peevishly', 'RB'),
#  ('wrote', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('margins', 'NNS'),
#  ('of', 'IN'),
#  ('file', 'NN'),
#  ('why', 'WRB'),
#  ('hasnt', 'NN'),
#  ('gandhi', 'NN'),
#  ('died', 'VBD'),
#  ('yet', 'RB'),
#  ('so', 'RB'),
#  ('all', 'JJ'),
#  ('notions', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('were', 'VBD'),
#  ('trying', 'VBG'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('their', 'PRP$'),
#  ('colonial', 'NN'),
#  ('enterprise', 'NN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('enlightened', 'JJ'),
#  ('despotism', 'NN'),
#  ('to', 'TO'),
#  ('try', 'VB'),
#  ('and', 'CC'),
#  ('bring', 'VB'),
#  ('the', 'DT'),
#  ('benefits', 'NNS'),
#  ('of', 'IN'),
#  ('colonialism', 'NN'),
#  ('and', 'CC'),
#  ('civilization', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('benighted', 'VBN'),
#  ('even', 'RB'),
#  ('i', 'VB'),
#  ('am', 'VBP'),
#  ('sorry', 'JJ'),
#  ('churchills', 'NNS'),
#  ('conduct', 'NN'),
#  ('in', 'IN'),
#  ('is', 'VBZ'),
#  ('simply', 'RB'),
#  ('one', 'CD'),
#  ('example', 'NN'),
#  ('of', 'IN'),
#  ('many', 'JJ'),
#  ('that', 'WDT'),
#  ('gave', 'VBD'),
#  ('light', 'VBN'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('myth', 'NN'),
#  ('as', 'IN'),
#  ('others', 'NNS'),
#  ('have', 'VBP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('proposition', 'NN'),
#  ('violence', 'NN'),
#  ('and', 'CC'),
#  ('racism', 'NN'),
#  ('were', 'VBD'),
#  ('the', 'DT'),
#  ('reality', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('colonial', 'JJ'),
#  ('experience', 'NN'),
#  ('and', 'CC'),
#  ('no', 'DT'),
#  ('wonder', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('sun', 'NN'),
#  ('never', 'RB'),
#  ('set', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('empire', 'NN'),
#  ('because', 'IN'),
#  ('even', 'RB'),
#  ('god', 'VBP'),
#  ('couldnt', 'JJ'),
#  ('trust', 'VBP'),
#  ('the', 'DT'),
#  ('english', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('dark', 'NN'),
#  ('let', 'VB'),
#  ('me', 'PRP'),
#  ('take', 'VB'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('concrete', 'JJ'),
#  ('example', 'NN'),
#  ('since', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('speaker', 'NN'),
#  ('mr', 'NN'),
#  ('lee', 'NN'),
#  ('suggested', 'VBD'),
#  ('these', 'DT'),
#  ('things', 'NNS'),
#  ('couldnt', 'VBP'),
#  ('be', 'VB'),
#  ('quantified', 'VBN'),
#  ('well', 'RB'),
#  ('let', 'VB'),
#  ('me', 'PRP'),
#  ('quantify', 'VB'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('for', 'IN'),
#  ('you', 'PRP'),
#  ('again', 'RB'),
#  ('i', 'VBP'),
#  ('am', 'VBP'),
#  ('sorry', 'RB'),
#  ('from', 'IN'),
#  ('an', 'DT'),
#  ('indian', 'JJ'),
#  ('perspective', 'NN'),
#  ('as', 'IN'),
#  ('others', 'NNS'),
#  ('have', 'VBP'),
#  ('spoken', 'VBN'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('countries', 'NNS'),
#  ('onesixth', 'IN'),
#  ('of', 'IN'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('forces', 'NNS'),
#  ('that', 'WDT'),
#  ('fought', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('war', 'NN'),
#  ('were', 'VBD'),
#  ('indian', 'JJ'),
#  ('indians', 'NNS'),
#  ('actually', 'RB'),
#  ('lost', 'VBD'),
#  ('their', 'PRP$'),
#  ('lives', 'NNS'),
#  ('in', 'IN'),
#  ('that', 'DT'),
#  ('war', 'NN'),
#  ('were', 'VBD'),
#  ('wounded', 'VBN'),
#  ('and', 'CC'),
#  ('another', 'DT'),
#  ('remained', 'VBD'),
#  ('missing', 'VBG'),
#  ('or', 'CC'),
#  ('in', 'IN'),
#  ('prison', 'NN'),
#  ('indian', 'JJ'),
#  ('taxpayers', 'NNS'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('cough', 'VB'),
#  ('up', 'RP'),
#  ('million', 'CD'),
#  ('pounds', 'NNS'),
#  ('in', 'IN'),
#  ('that', 'DT'),
#  ('times', 'NNS'),
#  ('money', 'NN'),
#  ('india', 'NN'),
#  ('supplied', 'VBN'),
#  ('million', 'CD'),
#  ('rounds', 'NNS'),
#  ('of', 'IN'),
#  ('ammunition', 'NN'),
#  ('rifles', 'NNS'),
#  ('and', 'CC'),
#  ('machine', 'NN'),
#  ('guns', 'NNS'),
#  ('million', 'CD'),
#  ('garments', 'NNS'),
#  ('were', 'VBD'),
#  ('stitched', 'VBN'),
#  ('and', 'CC'),
#  ('sent', 'VBN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('india', 'NN'),
#  ('and', 'CC'),
#  ('million', 'CD'),
#  ('indian', 'JJ'),
#  ('personnel', 'NNS'),
#  ('served', 'VBD'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('know', 'VBP'),
#  ('all', 'PDT'),
#  ('this', 'DT'),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('the', 'DT'),
#  ('commemoration', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('centenary', 'NN'),
#  ('has', 'VBZ'),
#  ('just', 'RB'),
#  ('taken', 'VBN'),
#  ('place', 'NN'),
#  ('but', 'CC'),
#  ('not', 'RB'),
#  ('just', 'RB'),
#  ('that', 'IN'),
#  ('india', 'NN'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('supply', 'VB'),
#  ('animals', 'NNS'),
#  ('million', 'CD'),
#  ('tons', 'NNS'),
#  ('of', 'IN'),
#  ('supplies', 'NNS'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('the', 'DT'),
#  ('total', 'JJ'),
#  ('value', 'NN'),
#  ('of', 'IN'),
#  ('everything', 'NN'),
#  ('that', 'WDT'),
#  ('was', 'VBD'),
#  ('taken', 'VBN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('india', 'JJ'),
#  ('india', 'NN'),
#  ('and', 'CC'),
#  ('india', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('suffering', 'VBG'),
#  ('from', 'IN'),
#  ('recession', 'NN'),
#  ('at', 'IN'),
#  ('that', 'DT'),
#  ('time', 'NN'),
#  ('and', 'CC'),
#  ('poverty', 'NN'),
#  ('and', 'CC'),
#  ('hunger', 'NN'),
#  ('was', 'VBD'),
#  ('in', 'IN'),
#  ('todays', 'JJ'),
#  ('money', 'NN'),
#  ('billion', 'CD'),
#  ('pounds', 'NNS'),
#  ('you', 'PRP'),
#  ('want', 'VBP'),
#  ('quantification', 'NN'),
#  ('its', 'PRP$'),
#  ('available', 'JJ'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('ii', 'VBP'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('even', 'RB'),
#  ('worse', 'JJR'),
#  ('million', 'CD'),
#  ('indians', 'NNS'),
#  ('in', 'IN'),
#  ...]

# %%
tagged2 = nltk.pos_tag(t2tokens)
tagged2
# Out:
# [('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('more', 'RBR'),
#  ('insidious', 'JJ'),
#  ('challenges', 'NNS'),
#  ('of', 'IN'),
#  ('colonialism', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('extent', 'NN'),
#  ('to', 'TO'),
#  ('which', 'WDT'),
#  ('our', 'PRP$'),
#  ('minds', 'NNS'),
#  ('are', 'VBP'),
#  ('colonized', 'VBN'),
#  ('as', 'IN'),
#  ('well', 'RB'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('colonization', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('mind', 'NN'),
#  ('takes', 'VBZ'),
#  ('some', 'DT'),
#  ('growing', 'VBG'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('for', 'IN'),
#  ('us', 'PRP'),
#  ('for', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('us', 'PRP'),
#  ('well', 'RB'),
#  ('never', 'RB'),
#  ('really', 'RB'),
#  ('grow', 'VB'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('i', 'JJ'),
#  ('mean', 'VBP'),
#  ('i', 'JJ'),
#  ('do', 'VBP'),
#  ('know', 'VB'),
#  ('that', 'IN'),
#  ('there', 'EX'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('many', 'JJ'),
#  ('who', 'WP'),
#  ('cant', 'VBP'),
#  ('help', 'NN'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('were', 'VBD'),
#  ('the', 'DT'),
#  ('identification', 'NN'),
#  ('with', 'IN'),
#  ('things', 'NNS'),
#  ('anglophone', 'NN'),
#  ('and', 'CC'),
#  ('anglophile', 'NN'),
#  ('because', 'IN'),
#  ('thats', 'NNS'),
#  ('really', 'RB'),
#  ('what', 'WP'),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('schooled', 'VBN'),
#  ('to', 'TO'),
#  ('appreciate', 'VB'),
#  ('i', 'NNS'),
#  ('have', 'VBP'),
#  ('argued', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('book', 'NN'),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  ('that', 'IN'),
#  ('my', 'PRP$'),
#  ('fondness', 'NN'),
#  ('for', 'IN'),
#  ('wodehouse', 'NN'),
#  ('and', 'CC'),
#  ('cricket', 'NN'),
#  ('which', 'WDT'),
#  ('you', 'PRP'),
#  ('mentioned', 'VBD'),
#  ('actually', 'RB'),
#  ('is', 'VBZ'),
#  ('despite', 'IN'),
#  ('in', 'IN'),
#  ('many', 'JJ'),
#  ('ways', 'NNS'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('english', 'JJ'),
#  ('origins', 'NNS'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('im', 'NN'),
#  ('even', 'RB'),
#  ('more', 'RBR'),
#  ('fond', 'NN'),
#  ('of', 'IN'),
#  ('cricket', 'NN'),
#  ('now', 'RB'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('regularly', 'RB'),
#  ('beat', 'VBD'),
#  ('the', 'DT'),
#  ('english', 'NN'),
#  ('at', 'IN'),
#  ('it', 'PRP'),
#  ('but', 'CC'),
#  ('famously', 'RB'),
#  ('an', 'DT'),
#  ('indian', 'JJ'),
#  ('game', 'NN'),
#  ('accidentally', 'RB'),
#  ('discovered', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('i', 'NN'),
#  ('think', 'VBP'),
#  ('thats', 'VBZ'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('line', 'NN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('sociologist', 'NN'),
#  ('called', 'VBN'),
#  ('ashish', 'JJ'),
#  ('nandy', 'NN'),
#  ('that', 'IN'),
#  ('its', 'PRP$'),
#  ('actually', 'RB'),
#  ('an', 'DT'),
#  ('indian', 'JJ'),
#  ('game', 'NN'),
#  ('accidentally', 'RB'),
#  ('discovered', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('i', 'NN'),
#  ('mean', 'VBP'),
#  ('clearly', 'RB'),
#  ('our', 'PRP$'),
#  ('climate', 'NN'),
#  ('is', 'VBZ'),
#  ('far', 'RB'),
#  ('more', 'RBR'),
#  ('suitable', 'JJ'),
#  ('for', 'IN'),
#  ('cricket', 'NN'),
#  ('than', 'IN'),
#  ('theirs', 'PRP'),
#  ('for', 'IN'),
#  ('one', 'CD'),
#  ('thing', 'NN'),
#  ('but', 'CC'),
#  ('anyway', 'RB'),
#  ('where', 'WRB'),
#  ('were', 'VBD'),
#  ('we', 'PRP'),
#  ('ive', 'VBP'),
#  ('lost', 'VBN'),
#  ('my', 'PRP$'),
#  ('train', 'NN'),
#  ('of', 'IN'),
#  ('thought', 'NN'),
#  ('thats', 'NNS'),
#  ('okay', 'IN'),
#  ('we', 'PRP'),
#  ('oh', 'VBP'),
#  ('yes', 'RB'),
#  ('pg', 'JJ'),
#  ('wodehouse', 'NN'),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  ('obviously', 'RB'),
#  ('the', 'DT'),
#  ('delights', 'NNS'),
#  ('of', 'IN'),
#  ('wodehouse', 'NN'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('delights', 'NNS'),
#  ('that', 'WDT'),
#  ('are', 'VBP'),
#  ('imparted', 'VBN'),
#  ('to', 'TO'),
#  ('you', 'PRP'),
#  ('by', 'IN'),
#  ('your', 'PRP$'),
#  ('appreciation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('english', 'JJ'),
#  ('language', 'NN'),
#  ('what', 'WP'),
#  ('he', 'PRP'),
#  ('does', 'VBZ'),
#  ('with', 'IN'),
#  ('stylistic', 'JJ'),
#  ('humor', 'NN'),
#  ('plotting', 'NN'),
#  ('and', 'CC'),
#  ('so', 'RB'),
#  ('on', 'IN'),
#  ('and', 'CC'),
#  ('so', 'RB'),
#  ('forth', 'JJ'),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('interesting', 'JJ'),
#  ('thing', 'NN'),
#  ('is', 'VBZ'),
#  ('precisely', 'RB'),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('that', 'DT'),
#  ('you', 'PRP'),
#  ('dont', 'VBP'),
#  ('actually', 'RB'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('an', 'DT'),
#  ('allegiance', 'NN'),
#  ('to', 'TO'),
#  ('britain', 'VB'),
#  ('as', 'RB'),
#  ('long', 'RB'),
#  ('as', 'IN'),
#  ('you', 'PRP'),
#  ('know', 'VBP'),
#  ('but', 'CC'),
#  ('you', 'PRP'),
#  ('dont', 'VBP'),
#  ('need', 'VB'),
#  ('the', 'DT'),
#  ('passport', 'NN'),
#  ('is', 'VBZ'),
#  ('english', 'JJ'),
#  ('language', 'NN'),
#  ('but', 'CC'),
#  ('you', 'PRP'),
#  ('dont', 'VBP'),
#  ('need', 'VB'),
#  ('a', 'DT'),
#  ('british', 'JJ'),
#  ('visa', 'NN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('there', 'RB'),
#  ('you', 'PRP'),
#  ('can', 'MD'),
#  ('sit', 'VB'),
#  ('in', 'IN'),
#  ('india', 'NN'),
#  ('surrounded', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('different', 'JJ'),
#  ('world', 'NN'),
#  ('from', 'IN'),
#  ('that', 'DT'),
#  ('which', 'WDT'),
#  ('he', 'PRP'),
#  ('describes', 'VBZ'),
#  ('and', 'CC'),
#  ('enjoy', 'VB'),
#  ('the', 'DT'),
#  ('escapism', 'NN'),
#  ('that', 'IN'),
#  ('his', 'PRP$'),
#  ('writing', 'NN'),
#  ('represents', 'VBZ'),
#  ('and', 'CC'),
#  ('so', 'IN'),
#  ('it', 'PRP'),
#  ('goes', 'VBZ'),
#  ('but', 'CC'),
#  ('i', 'JJ'),
#  ('realize', 'VBP'),
#  ('that', 'IN'),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('selfinterested', 'VBN'),
#  ('pleading', 'VBG'),
#  ('because', 'IN'),
#  ('obviously', 'RB'),
#  ('i', 'JJ'),
#  ('am', 'VBP'),
#  ('a', 'DT'),
#  ('product', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('system', 'NN'),
#  ('as', 'IN'),
#  ('you', 'PRP'),
#  ('rightly', 'RB'),
#  ('point', 'VB'),
#  ('out', 'RP'),
#  ('and', 'CC'),
#  ('i', 'VB'),
#  ('suppose', 'VBP'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('great', 'JJ'),
#  ('problems', 'NNS'),
#  ('with', 'IN'),
#  ('history', 'NN'),
#  ('is', 'VBZ'),
#  ('you', 'PRP'),
#  ('cant', 'JJ'),
#  ('establish', 'VB'),
#  ('the', 'DT'),
#  ('counterfactual', 'JJ'),
#  ('its', 'PRP$'),
#  ('impossible', 'JJ'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('what', 'WP'),
#  ('india', 'NN'),
#  ('might', 'MD'),
#  ('look', 'VB'),
#  ('like', 'IN'),
#  ('had', 'VBD'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('not', 'RB'),
#  ('been', 'VBN'),
#  ('there', 'EX'),
#  ('can', 'MD'),
#  ('i', 'VB'),
#  ('take', 'VB'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('those', 'DT'),
#  ('more', 'RBR'),
#  ('structural', 'JJ'),
#  ('things', 'NNS'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('india', 'VBZ'),
#  ('speaks', 'PDT'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('language', 'NN'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('india', 'NN'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('centralized', 'VBN'),
#  ('unitary', 'JJ'),
#  ('government', 'NN'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('democracy', 'NN'),
#  ('how', 'WRB'),
#  ('much', 'RB'),
#  ('has', 'VBZ'),
#  ('indias', 'JJ'),
#  ('way', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('being', 'VBG'),
#  ('made', 'VBN'),
#  ('easier', 'NN'),
#  ('by', 'IN'),
#  ('those', 'DT'),
#  ('legacies', 'NNS'),
#  ('highly', 'RB'),
#  ('contestant', 'JJ'),
#  ('no', 'DT'),
#  ('theres', 'VBZ'),
#  ('no', 'DT'),
#  ('question', 'NN'),
#  ('that', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('useful', 'JJ'),
#  ('to', 'TO'),
#  ('us', 'PRP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('english', 'JJ'),
#  ('language', 'NN'),
#  ('certainly', 'RB'),
#  ('but', 'CC'),
#  ('i', 'JJ'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('stress', 'VB'),
#  ('and', 'CC'),
#  ('i', 'VB'),
#  ('think', 'VBP'),
#  ('you', 'PRP'),
#  ('alluded', 'VBD'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('in', 'IN'),
#  ('your', 'PRP$'),
#  ('introduction', 'NN'),
#  ('that', 'IN'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('things', 'NNS'),
#  ('that', 'WDT'),
#  ('apologists', 'VBZ'),
#  ('for', 'IN'),
#  ('empire', 'NN'),
#  ('like', 'IN'),
#  ('to', 'TO'),
#  ('claim', 'VB'),
#  ('credit', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('english', 'JJ'),
#  ('language', 'NN'),
#  ('parliamentary', 'JJ'),
#  ('democracy', 'NN'),
#  ('the', 'DT'),
#  ('rule', 'NN'),
#  ('of', 'IN'),
#  ('law', 'NN'),
#  ('the', 'DT'),
#  ('railways', 'NNS'),
#  ('you', 'PRP'),
#  ('know', 'VBP'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('classic', 'JJ'),
#  ('clichés', 'NN'),
#  ('and', 'CC'),
#  ('for', 'IN'),
#  ('that', 'DT'),
#  ('matter', 'NN'),
#  ('even', 'RB'),
#  ('tea', 'VBZ'),
#  ('every', 'DT'),
#  ('single', 'JJ'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('things', 'NNS'),
#  ('was', 'VBD'),
#  ('brought', 'VBN'),
#  ('in', 'IN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('to', 'TO'),
#  ('advance', 'VB'),
#  ('their', 'PRP$'),
#  ('control', 'NN'),
#  ('of', 'IN'),
#  ('india', 'NN'),
#  ('to', 'TO'),
#  ('enhance', 'VB'),
#  ('their', 'PRP$'),
#  ('profits', 'NNS'),
#  ('and', 'CC'),
#  ('serve', 'VBP'),
#  ('their', 'PRP$'),
#  ('interests', 'NNS'),
#  ('not', 'RB'),
#  ('one', 'CD'),
#  ('was', 'VBD'),
#  ('intended', 'VBN'),
#  ('principally', 'RB'),
#  ('to', 'TO'),
#  ('benefit', 'VB'),
#  ('indians', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('when', 'WRB'),
#  ('they', 'PRP'),
#  ('left', 'VBD'),
#  ('they', 'PRP'),
#  ('couldnt', 'VBP'),
#  ('take', 'VB'),
#  ('this', 'DT'),
#  ('with', 'IN'),
#  ('them', 'PRP'),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('were', 'VBD'),
#  ('able', 'JJ'),
#  ('then', 'RB'),
#  ('to', 'TO'),
#  ('turn', 'VB'),
#  ('them', 'PRP'),
#  ('around', 'RB'),
#  ('to', 'TO'),
#  ('purposes', 'VB'),
#  ('the', 'DT'),
#  ('original', 'JJ'),
#  ('people', 'NNS'),
#  ('who', 'WP'),
#  ('introduced', 'VBD'),
#  ('them', 'PRP'),
#  ('would', 'MD'),
#  ('never', 'RB'),
#  ('have', 'VB'),
#  ('intended', 'VBN'),
#  ('is', 'VBZ'),
#  ('something', 'NN'),
#  ('that', 'IN'),
#  ('i', 'JJ'),
#  ('think', 'VBP'),
#  ('is', 'VBZ'),
#  ('more', 'RBR'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('credit', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('indian', 'JJ'),
#  ('nationals', 'NNS'),
#  ('than', 'IN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('english', 'JJ'),
#  ('im', 'NN'),
#  ('happy', 'JJ'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('examples', 'NNS'),
#  ('you', 'PRP'),
#  ('mentioned', 'VBD'),
#  ('you', 'PRP'),
#  ('take', 'VBP'),
#  ('language', 'NN'),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('had', 'VBD'),
#  ('no', 'DT'),
#  ('intention', 'NN'),
#  ('of', 'IN'),
#  ('imparting', 'VBG'),
#  ('education', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('masses', 'NNS'),
#  ('of', 'IN'),
#  ('indians', 'NNS'),
#  ('they', 'PRP'),
#  ('made', 'VBD'),
#  ('it', 'PRP'),
#  ('very', 'RB'),
#  ('clear', 'JJ'),
#  ('they', 'PRP'),
#  ('werent', 'VBD'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('spend', 'VB'),
#  ('the', 'DT'),
#  ('money', 'NN'),
#  ('doing', 'VBG'),
#  ('that', 'DT'),
#  ('and', 'CC'),
#  ('indeed', 'RB'),
#  ('as', 'RB'),
#  ('late', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('american', 'JJ'),
#  ('historian', 'NN'),
#  ('will', 'MD'),
#  ('durant', 'VB'),
#  ('observed', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('entire', 'JJ'),
#  ('budgets', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('for', 'IN'),
#  ('education', 'NN'),
#  ('in', 'IN'),
#  ('india', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('nursery', 'JJ'),
#  ('level', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('highest', 'JJS'),
#  ('university', 'NN'),
#  ('levels', 'NNS'),
#  ('amounted', 'VBD'),
#  ('to', 'TO'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('half', 'PDT'),
#  ('the', 'DT'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('budget', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('was', 'VBD'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('entire', 'JJ'),
#  ('country', 'NN'),
#  ('of', 'IN'),
#  ('india', 'NN'),
#  ('with', 'IN'),
#  ('at', 'IN'),
#  ('that', 'DT'),
#  ('point', 'NN'),
#  ('ten', 'RB'),
#  ('times', 'CC'),
#  ('as', 'RB'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('were', 'VBD'),
#  ('not', 'RB'),
#  ('interested', 'JJ'),
#  ('in', 'IN'),
#  ('investing', 'VBG'),
#  ('in', 'IN'),
#  ('education', 'NN'),
#  ('and', 'CC'),
#  ('even', 'RB'),
#  ('the', 'DT'),
#  ('english', 'JJ'),
#  ('language', 'NN'),
#  ('was', 'VBD'),
#  ('brought', 'VBN'),
#  ('in', 'IN'),
#  ('just', 'RB'),
#  ('to', 'TO'),
#  ('educate', 'VB'),
#  ('a', 'DT'),
#  ('narrow', 'JJ'),
#  ('class', 'NN'),
#  ('of', 'IN'),
#  ('interpreters', 'NNS'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('governors', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('governed', 'JJ'),
#  ('people', 'NNS'),
#  ('who', 'WP'),
#  ('would', 'MD'),
#  ('help', 'VB'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('by', 'IN'),
#  ('constituting', 'VBG'),
#  ('a', 'DT'),
#  ('buffer', 'NN'),
#  ('between', 'IN'),
#  ('them', 'PRP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('dirty', 'NN'),
#  ('masses', 'NNS'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('rule', 'NN'),
#  ('i', 'IN'),
#  ('mean', 'VBP'),
#  ('that', 'WDT'),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('much', 'JJ'),
#  ('the', 'DT'),
#  ('actual', 'JJ'),
#  ('macaulay', 'NN'),
#  ('actually', 'RB'),
#  ('said', 'VBD'),
#  ('this', 'DT'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('notorious', 'JJ'),
#  ('minute', 'NN'),
#  ('on', 'IN'),
#  ('education', 'NN'),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('create', 'VB'),
#  ('a', 'DT'),
#  ('class', 'NN'),
#  ('of', 'IN'),
#  ('indians', 'NNS'),
#  ('indian', 'JJ'),
#  ('in', 'IN'),
#  ('skin', 'NN'),
#  ('and', 'CC'),
#  ('color', 'NN'),
#  ('but', 'CC'),
#  ('english', 'JJ'),
#  ('in', 'IN'),
#  ('opinions', 'NNS'),
#  ('and', 'CC'),
#  ('tastes', 'NNS'),
#  ('and', 'CC'),
#  ('morals', 'NNS'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('intellect', 'JJ'),
#  ('those', 'DT'),
#  ('were', 'VBD'),
#  ('his', 'PRP$'),
#  ('exact', 'JJ'),
#  ('words', 'NNS'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('to', 'TO'),
#  ('serve', 'VB'),
#  ('their', 'PRP$'),
#  ('purposes', 'NNS'),
#  ('now', 'RB'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('indians', 'NNS'),
#  ('then', 'RB'),
#  ('used', 'VBD'),
#  ('english', 'JJ'),
#  ('to', 'TO'),
#  ('open', 'VB'),
#  ('up', 'RP'),
#  ('on', 'IN'),
#  ('another', 'DT'),
#  ('world', 'NN'),
#  ('of', 'IN'),
#  ('ideas', 'NNS'),
#  ('often', 'RB'),
#  ('very', 'RB'),
#  ('radical', 'JJ'),
#  ('and', 'CC'),
#  ('critical', 'JJ'),
#  ('ideas', 'NNS'),
#  ('and', 'CC'),
#  ('ideas', 'NNS'),
#  ('that', 'WDT'),
#  ('eventually', 'RB'),
#  ('made', 'VBD'),
#  ('english', 'VB'),
#  ('a', 'DT'),
#  ('language', 'NN'),
#  ('of', 'IN'),
#  ('indian', 'JJ'),
#  ('nationalism', 'NN'),
#  ('our', 'PRP$'),
#  ('first', 'JJ'),
#  ('prime', 'JJ'),
#  ('minister', 'NN'),
#  ('jawaharlal', 'NN'),
#  ('nehru', 'JJ'),
#  ('wrote', 'VBD'),
#  ('his', 'PRP$'),
#  ('classic', 'JJ'),
#  ('the', 'DT'),
#  ('discovery', 'NN'),
#  ('of', 'IN'),
#  ('india', 'NN'),
#  ('in', 'IN'),
#  ('english', 'JJ'),
#  ('so', 'IN'),
#  ('the', 'DT'),
#  ('indian', 'JJ'),
#  ('nationalist', 'NN'),
#  ('discovered', 'VBD'),
#  ('india', 'NN'),
#  ('in', 'IN'),
#  ('english', 'JJ'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('were', 'VBD'),
#  ('but', 'CC'),
#  ('that', 'DT'),
#  ('was', 'VBD'),
#  ('our', 'PRP$'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('like', 'VBP'),
#  ('change', 'NN'),
#  ('of', 'IN'),
#  ('what', 'WP'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('had', 'VBD'),
#  ('intended', 'VBN'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('democracy', 'NN'),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ('mentioned', 'VBD'),
#  ('political', 'JJ'),
#  ('unity', 'NN'),
#  ('well', 'RB'),
#  ('political', 'JJ'),
#  ('unity', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('one', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('point', 'NN'),
#  ('to', 'TO'),
#  ('with', 'IN'),
#  ('pride', 'NN'),
#  ('that', 'IN'),
#  ('they', 'PRP'),
#  ('came', 'VBD'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('bunch', 'NN'),
#  ('of', 'IN'),
#  ('warring', 'VBG'),
#  ('principalities', 'NNS'),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('made', 'VBD'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('not', 'RB'),
#  ('so', 'RB'),
#  ('for', 'IN'),
#  ('years', 'NNS'),
#  ('before', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('ever', 'RB'),
#  ('set', 'VBP'),
#  ('foot', 'NN'),
#  ('on', 'IN'),
#  ('india', 'NN'),
#  ('there', 'EX'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('clear', 'JJ'),
#  ('sense', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('common', 'JJ'),
#  ('civilizational', 'JJ'),
#  ('unity', 'NN'),
#  ('and', 'CC'),
#  ('an', 'DT'),
#  ('aspiration', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('monarchs', 'NN'),
#  ('to', 'TO'),
#  ('consolidate', 'VB'),
#  ('that', 'IN'),
#  ('territorially', 'RB'),
#  ('now', 'RB'),
#  ('obviously', 'RB'),
#  ('they', 'PRP'),
#  ('couldnt', 'VBP'),
#  ('i', 'JJ'),
#  ('mean', 'VBP'),
#  ('we', 'PRP'),
#  ('had', 'VBD'),
#  ('two', 'CD'),
#  ('people', 'NNS'),
#  ('who', 'WP'),
#  ('came', 'VBD'),
#  ('very', 'RB'),
#  ('close', 'RB'),
#  ('there', 'EX'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('mauryan', 'JJ'),
#  ('empire', 'NN'),
#  ('ashoka', 'NN'),
#  ('and', 'CC'),
#  ('chandragupta', 'NN'),
#  ('who', 'WP'),
#  ('controlled', 'VBD'),
#  ('about', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('subcontinent', 'NN'),
#  ('including', 'VBG'),
#  ('afghanistan', 'NNS'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('the', 'DT'),
#  ('mughals', 'NNS'),
#  ('particularly', 'RB'),
#  ('akbar', 'NN'),
#  ('and', 'CC'),
#  ('aurangzeb', 'NN'),
#  ('they', 'PRP'),
#  ('controlled', 'VBD'),
#  ('about', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('subcontinent', 'NN'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('extent', 'NN'),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('everyone', 'NN'),
#  ('tried', 'VBD'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('it', 'PRP'),
#  ('aspired', 'VB'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('it', 'PRP'),
#  ('and', 'CC'),
#  ('failed', 'VBD'),
#  ('in', 'IN'),
#  ('trying', 'VBG'),
#  ('shows', 'NNS'),
#  ('that', 'IN'),
#  ('if', 'IN'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('hadnt', 'NN'),
#  ('succeeded', 'VBD'),
#  ('somebody', 'NN'),
#  ('else', 'RB'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('time', 'NN'),
#  ...]

# %% [markdown]
# ###Plotting the freqency bar graph for POS tags

# %%
dict1 = {}
for a, b in tagged1:
    if(b not in dict1):
        dict1[b] = 1
    else:
        dict1[b] += 1

sorted_d1 = dict(sorted(dict1.items(), key=operator.itemgetter(1), reverse=True))


N = 20
out1 = dict(list(sorted_d1.items())[0: N])

plt.bar(out1.keys(), out1.values())
plt.xlabel('TAGS')
plt.ylabel('Count')
plt.show()

# %%
dict2 = {}
for a, b in tagged2:
    if(b not in dict2):
        dict2[b] = 1
    else:
        dict2[b] += 1

sorted_d2 = dict(sorted(dict2.items(), key=operator.itemgetter(1), reverse=True))


N = 20
out1 = dict(list(sorted_d2.items())[0: N])

plt.bar(out1.keys(), out1.values())
plt.xlabel('TAGS')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #**Round 2**

# %% [markdown]
# Seperating nouns and verbs

# %%
T1_nouns = []
T1_verbs = []

for i in tagged1:
  if(i[1] == "NN" or i[1] == "NNS" or i[1] == "NNP" or i[1] =="NNPS"):
    T1_nouns.append(i)
  elif (i[1]=="VB" or i[1]=="VBD" or i[1]=="VBG" or i[1]=="VBN" or i[1]=="VBP" or i[1]=="VBZ"):
    T1_verbs.append(i)

print(T1_nouns)
print(T1_verbs)
# Out:
# [('madam', 'NN'), ('president', 'NN'), ('ladies', 'NNS'), ('house', 'NN'), ('i', 'NN'), ('minutes', 'NNS'), ('hands', 'NNS'), ('institution', 'NN'), ('i', 'NN'), ('henry', 'NN'), ('school', 'NN'), ('speaking', 'NN'), ('henry', 'NN'), ('viii', 'NN'), ('wives', 'NNS'), ('speaker', 'NN'), ('evening', 'NN'), ('henry', 'NN'), ('wife', 'NN'), ('whats', 'NNS'), ('i', 'NN'), ('attention', 'NN'), ('arguments', 'NNS'), ('opposition', 'NN'), ('today', 'NN'), ('example', 'NN'), ('richard', 'NN'), ('ottaway', 'NN'), ('idea', 'NN'), ('situation', 'NN'), ('colonies', 'NNS'), ('experience', 'NN'), ('colonialism', 'NN'), ('example', 'NN'), ('richard', 'NN'), ('india', 'NN'), ('share', 'NN'), ('world', 'NN'), ('economy', 'NN'), ('britain', 'NN'), ('shores', 'NNS'), ('time', 'NN'), ('india', 'NN'), ('benefit', 'NN'), ('britain', 'NN'), ('britains', 'NNS'), ('years', 'NNS'), ('depredations', 'NNS'), ('india', 'NN'), ('fact', 'NN'), ('britains', 'NNS'), ('revolution', 'NN'), ('deindustrialization', 'NN'), ('india', 'NN'), ('handloom', 'NN'), ('weavers', 'NNS'), ('example', 'NN'), ('world', 'NN'), ('products', 'NNS'), ('world', 'NN'), ('britain', 'NN'), ('weavers', 'NNS'), ('muslin', 'NN'), ('britain', 'NN'), ('thumbs', 'NNS'), ('looms', 'NNS'), ('tariffs', 'NNS'), ('duties', 'NNS'), ('cloth', 'NN'), ('products', 'NNS'), ('course', 'NN'), ('materials', 'NNS'), ('india', 'NN'), ('shipping', 'NN'), ('cloth', 'NN'), ('worlds', 'NNS'), ('markets', 'NNS'), ('products', 'NNS'), ('dark', 'NN'), ('mills', 'NNS'), ('victoria', 'NN'), ('england', 'NN'), ('weavers', 'NNS'), ('india', 'NN'), ('beggars', 'NNS'), ('world', 'NN'), ('exporter', 'NN'), ('cloth', 'NN'), ('importer', 'NN'), ('world', 'NN'), ('trade', 'NN'), ('colonialists', 'NNS'), ('robert', 'NN'), ('boroughs', 'NNS'), ('england', 'NN'), ('proceeds', 'NNS'), ('loot', 'NN'), ('india', 'NN'), ('hindi', 'NN'), ('word', 'NN'), ('loot', 'NN'), ('habits', 'NNS'), ('gall', 'NN'), ('india', 'NN'), ('country', 'NN'), ('country', 'NN'), ('end', 'NN'), ('century', 'NN'), ('fact', 'NN'), ('india', 'NN'), ('cash', 'NN'), ('worlds', 'NNS'), ('purchaser', 'NN'), ('goods', 'NNS'), ('exports', 'NNS'), ('source', 'NN'), ('employment', 'NN'), ('servants', 'NNS'), ('oppression', 'NN'), ('families', 'NNS'), ('money', 'NN'), ('economy', 'NN'), ('fifth', 'NN'), ('elites', 'NNS'), ('class', 'NN'), ('britain', 'NN'), ('century', 'NN'), ('money', 'NN'), ('africans', 'NNS'), ('waters', 'NNS'), ('fact', 'NN'), ('slavery', 'NN'), ('compensation', 'NN'), ('pounds', 'NNS'), ('reparations', 'NNS'), ('lives', 'NNS'), ('slavery', 'NN'), ('property', 'NN'), ('i', 'NN'), ('fact', 'NN'), ('wifi', 'NN'), ('password', 'NN'), ('union', 'NN'), ('name', 'NN'), ('mr', 'NN'), ('gladstone', 'NN'), ('hero', 'NN'), ('family', 'NN'), ('compensation', 'NN'), ('india', 'NN'), ('indians', 'NNS'), ('starvation', 'NN'), ('famines', 'NNS'), ('example', 'NN'), ('course', 'NN'), ('famine', 'NN'), ('world', 'NN'), ('war', 'NN'), ('ii', 'NN'), ('people', 'NNS'), ('winston', 'NN'), ('churchill', 'NN'), ('matter', 'NN'), ('policy', 'NN'), ('supplies', 'NNS'), ('civilians', 'NNS'), ('bengal', 'NN'), ('tummies', 'NNS'), ('europeans', 'NNS'), ('reserve', 'NN'), ('stockpiles', 'NNS'), ('starvation', 'NN'), ('bengalis', 'NN'), ('greeks', 'NN'), ('churchills', 'NNS'), ('quote', 'NN'), ('officials', 'NNS'), ('people', 'NNS'), ('decision', 'NN'), ('margins', 'NNS'), ('file', 'NN'), ('hasnt', 'NN'), ('gandhi', 'NN'), ('notions', 'NNS'), ('colonial', 'NN'), ('enterprise', 'NN'), ('despotism', 'NN'), ('benefits', 'NNS'), ('colonialism', 'NN'), ('civilization', 'NN'), ('churchills', 'NNS'), ('conduct', 'NN'), ('example', 'NN'), ('myth', 'NN'), ('others', 'NNS'), ('proposition', 'NN'), ('violence', 'NN'), ('racism', 'NN'), ('reality', 'NN'), ('experience', 'NN'), ('wonder', 'NN'), ('sun', 'NN'), ('empire', 'NN'), ('english', 'NN'), ('dark', 'NN'), ('world', 'NN'), ('war', 'NN'), ('i', 'NN'), ('example', 'NN'), ('speaker', 'NN'), ('mr', 'NN'), ('lee', 'NN'), ('things', 'N ...
# [('standing', 'VBG'), ('was', 'VBD'), ('going', 'VBG'), ('assure', 'VB'), ('i', 'VBZ'), ('said', 'VBD'), ('i', 'VBP'), ('keep', 'VB'), ('finding', 'VBG'), ('seem', 'VB'), ('i', 'VBP'), ('feel', 'VBP'), ('viiis', 'VBP'), ('i', 'VBD'), ('expected', 'VBN'), ('i', 'VB'), ('am', 'VBP'), ('do', 'VB'), ('do', 'VB'), ('is', 'VBZ'), ('pay', 'VB'), ('have', 'VBP'), ('advanced', 'VBN'), ('had', 'VBD'), ('suggesting', 'VBG'), ('challenging', 'VBG'), ('be', 'VB'), ('argued', 'VBN'), ('was', 'VBD'), ('worsened', 'VBN'), ('stand', 'VBP'), ('offer', 'VB'), ('arrived', 'VBD'), ('was', 'VBD'), ('left', 'VBD'), ('was', 'VBD'), ('below', 'VB'), ('had', 'VBD'), ('been', 'VBN'), ('governed', 'VBN'), ('rise', 'VBP'), ('was', 'VBD'), ('financed', 'VBN'), ('was', 'VBD'), ('premised', 'VBN'), ('famed', 'VBN'), ('were', 'VBD'), ('exported', 'VBN'), ('came', 'VBD'), ('were', 'VBD'), ('making', 'VBG'), ('was', 'VBD'), ('said', 'VBD'), ('came', 'VBD'), ('smashed', 'VBN'), ('broke', 'VBD'), ('imposed', 'VBN'), ('started', 'VBD'), ('taking', 'VBG'), ('manufactured', 'VBD'), ('flooding', 'VBG'), ('became', 'VBD'), ('meant', 'VBD'), ('became', 'VBD'), ('india', 'VB'), ('went', 'VBD'), ('being', 'VBG'), ('having', 'VBG'), ('bought', 'VBD'), ('taking', 'VBG'), ('had', 'VBD'), ('call', 'VB'), ('belonged', 'VBD'), ('did', 'VBD'), ('was', 'VBD'), ('ensure', 'VB'), ('belonged', 'VBD'), ('is', 'VBZ'), ('was', 'VBD'), ('britains', 'VBZ'), ('cow', 'VBD'), ('paid', 'VBN'), ('paid', 'VBD'), ('has', 'VBZ'), ('been', 'VBN'), ('pointed', 'VBN'), ('made', 'VBD'), ('owed', 'VBD'), ('transporting', 'VBG'), ('was', 'VBD'), ('abolished', 'VBN'), ('happened', 'VBD'), ('was', 'VBD'), ('was', 'VBD'), ('paid', 'VBN'), ('had', 'VBD'), ('lost', 'VBN'), ('had', 'VBD'), ('suffered', 'VBN'), ('been', 'VBN'), ('oppressed', 'VBN'), ('had', 'VBD'), ('lost', 'VBN'), ('was', 'VBD'), ('struck', 'VBN'), ('commemorates', 'VBZ'), ('am', 'VBP'), ('was', 'VBD'), ('benefited', 'VBD'), ('staying', 'VBG'), ('died', 'VBN'), ('was', 'VBD'), ('was', 'VBD'), ('died', 'VBD'), ('written', 'VBN'), ('proceeded', 'VBN'), ('divert', 'VB'), ('sturdy', 'VB'), ('said', 'VBD'), ('mattered', 'VBD'), ('wrote', 'VBD'), ('pointing', 'VBG'), ('were', 'VBD'), ('dying', 'VBG'), ('wrote', 'VBD'), ('died', 'VBD'), ('were', 'VBD'), ('trying', 'VBG'), ('do', 'VB'), ('try', 'VB'), ('bring', 'VB'), ('benighted', 'VBN'), ('i', 'VB'), ('am', 'VBP'), ('is', 'VBZ'), ('gave', 'VBD'), ('light', 'VBN'), ('have', 'VBP'), ('said', 'VBD'), ('were', 'VBD'), ('set', 'VBN'), ('god', 'VBP'), ('trust', 'VBP'), ('let', 'VB'), ('take', 'VB'), ('suggested', 'VBD'), ('couldnt', 'VBP'), ('be', 'VB'), ('quantified', 'VBN'), ('let', 'VB'), ('quantify', 'VB'), ('i', 'VBP'), ('am', 'VBP'), ('have', 'VBP'), ('spoken', 'VBN'), ('fought', 'VBD'), ('were', 'VBD'), ('lost', 'VBD'), ('were', 'VBD'), ('wounded', 'VBN'), ('remained', 'VBD'), ('missing', 'VBG'), ('had', 'VBD'), ('cough', 'VB'), ('supplied', 'VBN'), ('were', 'VBD'), ('stitched', 'VBN'), ('sent', 'VBN'), ('served', 'VBD'), ('know', 'VBP'), ('has', 'VBZ'), ('taken', 'VBN'), ('had', 'VBD'), ('supply', 'VB'), ('was', 'VBD'), ('taken', 'VBN'), ('suffering', 'VBG'), ('was', 'VBD'), ('want', 'VBP'), ('ii', 'VBP'), ('was', 'VBD'), ('wont', 'VBP'), ('believe', 'VBP'), ('britains', 'VBZ'), ('was', 'VBD'), ('owed', 'VBN'), ('india', 'VB'), ('paid', 'VBN'), ('mentioned', 'VBD'), ('is', 'VBZ'), ('cemented', 'VBN'), ('had', 'VBD'), ('tried', 'VBN'), ('send', 'VB'), ('had', 'VBD'), ('failed', 'VBN'), ('am', 'VBP'), ('say', 'VB'), ('came', 'VBD'), ('was', 'VBD'), ('had', 'VBD'), ('i', 'VBP'), ('am', 'VBP'), ('had', 'VBD'), ('speak', 'VB'), ('engaged', 'VBD'), ('is', 'VBZ'), ('brought', 'VBD'), ('scotland', 'VB'), ('pulled', 'VBN'), ('scotland', 'VBP'), ('is', 'VBZ'), ('are', 'VBP'), ('loosening', 'VBG'), ('have', 'VBP'), ('heard', 'VBN'), ('has', 'VBZ'), ('been', 'VBN'), ('let', 'VB'), ('tell', 'VB'), ('has', 'VBZ'), ('pointed', 'VBN'), ('were', 'VBD'), ('built', 'VBN'), ('serve', 'VB'), ('add', 'VB'), ('have' ...

# %% [markdown]
# Categorizing and getting frequency of nouns

# %%
from nltk.corpus import wordnet
nltk.download('wordnet')
nltk.download('omw-1.4')
T1_nouns_dict = {}

for i in T1_nouns:
  syn = wordnet.synsets(i[0])
  for j in syn:
    if j.lexname()[0]=='n':
      if j.lexname() in T1_nouns_dict:
        T1_nouns_dict[j.lexname()]+=1
      else:
        T1_nouns_dict[j.lexname()]=1

t3 = sorted(T1_nouns_dict.items(), key=lambda item: item[1], reverse=True)

for i in t3:
  print(i[0][5:] + ": " + str(i[1]))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# act: 259
# communication: 244
# cognition: 225
# group: 215
# person: 195
# artifact: 172
# location: 141
# possession: 120
# state: 112
# quantity: 107
# time: 104
# attribute: 100
# event: 59
# object: 58
# substance: 25
# animal: 22
# body: 21
# process: 18
# Tops: 17
# food: 14
# phenomenon: 13
# feeling: 13
# relation: 12
# shape: 6
# motive: 3
# plant: 1

# %% [markdown]
# Categorizing and getting frequency of verbs

# %%
T1_verbs_dict = {}
for i in T1_verbs:
  syn = wordnet.synsets(i[0])
  for j in syn:
    if j.lexname()[0]=='v':
      if j.lexname() in T1_verbs_dict:
        T1_verbs_dict[j.lexname()]+=1
      else:
        T1_verbs_dict[j.lexname()]=1

t4 = sorted(T1_verbs_dict.items(), key=lambda item: item[1], reverse=True)

for i in t4:
  print(i[0][5:] + ": " + str(i[1]))
# Out:
# stative: 1769
# possession: 639
# communication: 450
# social: 380
# change: 331
# cognition: 228
# creation: 213
# contact: 197
# motion: 189
# body: 189
# perception: 110
# consumption: 93
# competition: 80
# emotion: 45
# weather: 1

# %% [markdown]
# Histogram for nouns

# %%
import matplotlib.pyplot as mplp

mplp.bar(T1_nouns_dict.keys(), T1_nouns_dict.values(),color='b')
y_pos = range(len(T1_nouns_dict.keys()))
mplp.xticks(y_pos, T1_nouns_dict.keys(), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f005fb2ab80>,
#   <matplotlib.axis.XTick at 0x7f005fb2abe0>,
#   <matplotlib.axis.XTick at 0x7f005f969a90>,
#   <matplotlib.axis.XTick at 0x7f0062c40af0>,
#   <matplotlib.axis.XTick at 0x7f00629f29a0>,
#   <matplotlib.axis.XTick at 0x7f00629f28b0>,
#   <matplotlib.axis.XTick at 0x7f005fb209a0>,
#   <matplotlib.axis.XTick at 0x7f00629a1a00>,
#   <matplotlib.axis.XTick at 0x7f00624029d0>,
#   <matplotlib.axis.XTick at 0x7f00623e7550>,
#   <matplotlib.axis.XTick at 0x7f00629a1190>,
#   <matplotlib.axis.XTick at 0x7f00623e7e20>,
#   <matplotlib.axis.XTick at 0x7f00623df0a0>,
#   <matplotlib.axis.XTick at 0x7f005fb07520>,
#   <matplotlib.axis.XTick at 0x7f005fb07ee0>,
#   <matplotlib.axis.XTick at 0x7f00623df880>,
#   <matplotlib.axis.XTick at 0x7f00624f3640>,
#   <matplotlib.axis.XTick at 0x7f00627f5b20>,
#   <matplotlib.axis.XTick at 0x7f00627f5b50>,
#   <matplotlib.axis.XTick at 0x7f0062507b50>,
#   <matplotlib.axis.XTick at 0x7f00623e7c10>,
#   <matplotlib.axis.XTick at 0x7f006282bfd0>,
#   <matplotlib.axis.XTick at 0x7f006282bac0>,
#   <matplotlib.axis.XTick at 0x7f006242a610>,
#   <matplotlib.axis.XTick at 0x7f006280be50>,
#   <matplotlib.axis.XTick at 0x7f00625078b0>],
#  [Text(0, 0, 'noun.person'),
#   Text(1, 0, 'noun.act'),
#   Text(2, 0, 'noun.artifact'),
#   Text(3, 0, 'noun.group'),
#   Text(4, 0, 'noun.location'),
#   Text(5, 0, 'noun.substance'),
#   Text(6, 0, 'noun.quantity'),
#   Text(7, 0, 'noun.communication'),
#   Text(8, 0, 'noun.time'),
#   Text(9, 0, 'noun.attribute'),
#   Text(10, 0, 'noun.body'),
#   Text(11, 0, 'noun.cognition'),
#   Text(12, 0, 'noun.animal'),
#   Text(13, 0, 'noun.relation'),
#   Text(14, 0, 'noun.event'),
#   Text(15, 0, 'noun.state'),
#   Text(16, 0, 'noun.possession'),
#   Text(17, 0, 'noun.object'),
#   Text(18, 0, 'noun.Tops'),
#   Text(19, 0, 'noun.phenomenon'),
#   Text(20, 0, 'noun.food'),
#   Text(21, 0, 'noun.process'),
#   Text(22, 0, 'noun.plant'),
#   Text(23, 0, 'noun.feeling'),
#   Text(24, 0, 'noun.motive'),
#   Text(25, 0, 'noun.shape')])

# %% [markdown]
# Histogram for verbs

# %%
mplp.bar(T1_verbs_dict.keys(), T1_verbs_dict.values(),color='b')
y_pos = range(len(T1_verbs_dict.keys()))
mplp.xticks(y_pos, T1_verbs_dict.keys(), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f0095cc89a0>,
#   <matplotlib.axis.XTick at 0x7f0095cc8e80>,
#   <matplotlib.axis.XTick at 0x7f0095cc8100>,
#   <matplotlib.axis.XTick at 0x7f006261d190>,
#   <matplotlib.axis.XTick at 0x7f006261ae20>,
#   <matplotlib.axis.XTick at 0x7f006261a7c0>,
#   <matplotlib.axis.XTick at 0x7f0062692820>,
#   <matplotlib.axis.XTick at 0x7f00626267c0>,
#   <matplotlib.axis.XTick at 0x7f0062626ee0>,
#   <matplotlib.axis.XTick at 0x7f0062626af0>,
#   <matplotlib.axis.XTick at 0x7f0062647580>,
#   <matplotlib.axis.XTick at 0x7f00625e5640>,
#   <matplotlib.axis.XTick at 0x7f00625e5d90>,
#   <matplotlib.axis.XTick at 0x7f00626418b0>,
#   <matplotlib.axis.XTick at 0x7f00625e57c0>],
#  [Text(0, 0, 'verb.contact'),
#   Text(1, 0, 'verb.stative'),
#   Text(2, 0, 'verb.cognition'),
#   Text(3, 0, 'verb.competition'),
#   Text(4, 0, 'verb.social'),
#   Text(5, 0, 'verb.possession'),
#   Text(6, 0, 'verb.motion'),
#   Text(7, 0, 'verb.change'),
#   Text(8, 0, 'verb.perception'),
#   Text(9, 0, 'verb.consumption'),
#   Text(10, 0, 'verb.communication'),
#   Text(11, 0, 'verb.emotion'),
#   Text(12, 0, 'verb.creation'),
#   Text(13, 0, 'verb.body'),
#   Text(14, 0, 'verb.weather')])

# %% [markdown]
# Entity Recognition

# %%
import spacy
from spacy import displacy
import en_core_web_sm
from collections import Counter

NER = en_core_web_sm.load()
nlp = spacy.load('en_core_web_sm') 
nlp.max_length = 100000000*1000000000

doc1 = nlp(t1)
print([(X.text, X.label_) for X in doc1.ents])
# Out:
# [('eight minutes', 'TIME'), ('the henry viii school of public speaking', 'ORG'), ('henry viii', 'PERSON'), ('seventh', 'ORDINAL'), ('eight', 'CARDINAL'), ('today', 'DATE'), ('richard ottaway', 'PERSON'), ('british', 'NORP'), ('indian', 'NORP'), ('richard india', 'PERSON'), ('britain', 'GPE'), ('british', 'NORP'), ('india', 'GPE'), ('britain', 'GPE'), ('years', 'DATE'), ('india', 'GPE'), ('india', 'GPE'), ('britain', 'GPE'), ('britain', 'GPE'), ('india', 'GPE'), ('england', 'GPE'), ('india', 'GPE'), ('india', 'GPE'), ('robert', 'PERSON'), ('england', 'GPE'), ('india', 'GPE'), ('british', 'NORP'), ('india', 'GPE'), ('india', 'GPE'), ('british', 'NORP'), ('british', 'NORP'), ('british', 'NORP'), ('one fifth', 'CARDINAL'), ('britain', 'GPE'), ('the th century', 'DATE'), ('million', 'CARDINAL'), ('india', 'GPE'), ('between million and million', 'CARDINAL'), ('indians', 'NORP'), ('british', 'NORP'), ('the world war ii', 'EVENT'), ('million', 'CARDINAL'), ('winston churchill deliberately', 'GPE'), ('europeans', 'NORP'), ('bengalis', 'NORP'), ('greeks', 'PERSON'), ('british', 'NORP'), ('gandhi', 'PERSON'), ('british', 'NORP'), ('one', 'CARDINAL'), ('british', 'NORP'), ('english', 'LANGUAGE'), ('first', 'ORDINAL'), ('lee', 'PERSON'), ('indian', 'NORP'), ('british', 'NORP'), ('indian indians', 'NORP'), ('indian', 'NORP'), ('million', 'CARDINAL'), ('india', 'GPE'), ('million', 'CARDINAL'), ('indian', 'NORP'), ('india', 'GPE'), ('million tons', 'QUANTITY'), ('india', 'GPE'), ('india', 'GPE'), ('india', 'GPE'), ('money billion pounds', 'MONEY'), ('world war ii', 'EVENT'), ('million', 'CARDINAL'), ('indians', 'NORP'), ('billion pounds', 'MONEY'), ('india', 'GPE'), ('india', 'GPE'), ('india', 'GPE'), ('scotland', 'GPE'), ('india', 'GPE'), ('first', 'ORDINAL'), ('jamaican', 'NORP'), ('british', 'NORP'), ('britain', 'GPE'), ('indian', 'NORP'), ('jamaican', 'NORP'), ('indian', 'NORP'), ('britain', 'GPE'), ('british', 'NORP'), ('indian', 'NORP'), ('indians', 'NORP'), ('one mile', 'QUANTITY'), ('indian', 'NORP'), ('canada', 'GPE'), ('australia', 'GPE'), ('britain', 'GPE'), ('british', 'NORP'), ('indian', 'NORP'), ('richard ottaway', 'PERSON'), ('british', 'NORP'), ('india', 'GPE'), ('british', 'NORP'), ('india', 'GPE'), ('india', 'GPE'), ('somalia', 'GPE'), ('africans', 'NORP'), ('british', 'NORP'), ('germany', 'GPE'), ('israel', 'GPE'), ('poland', 'GPE'), ('charles william brunt', 'PERSON'), ('libya', 'GPE'), ('korea', 'GPE'), ('britain', 'GPE'), ('new zealand', 'GPE'), ('louis reminded', 'PERSON'), ('texas', 'GPE'), ('texas', 'GPE'), ('years', 'DATE'), ('years', 'DATE'), ('british', 'NORP'), ('first', 'ORDINAL'), ('lee', 'PERSON'), ('mugabe', 'PERSON'), ('the old days', 'DATE'), ('britain', 'GPE'), ('one pound', 'QUANTITY'), ('the next years', 'DATE'), ('the last years', 'DATE'), ('britain', 'GPE'), ('india', 'GPE')]

# %% [markdown]
# Extracting random passage from the speech

# %%
para_T1 = t1[500:3000] 
doc2 = NER(para_T1)

displacy.render(doc2, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">am not sure how to do it any differently perhaps what i should do is really try and pay attention to the arguments that have advanced by the opposition
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  we had for example sir
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     richard ottaway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  suggesting challenging the very idea that it could be argued that the economic situation of the colonies was actually worsened by the experience of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     british
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  colonialism well i stand to offer you the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  example sir
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     richard india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  share of the world economy when
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  arrived on its shores was by the time the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     british
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  left it was down to below why simply because
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  had been governed for the benefit of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  britains rise for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was financed by its depredations in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in fact britains industrial revolution was actually premised upon the deindustrialization of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  the handloom weavers for example famed across the world whose products were exported around the world
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  came right in there were actually these weavers making fine muslin as light as woven wear it was said and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  came right in smashed their thumbs broke their looms imposed tariffs and duties on their cloth and products and started of course taking the raw materials from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and shipping back manufactured cloth flooding the worlds markets with what became the products of the dark and satanic mills of the victoria in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     england
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  that meant that the weavers in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  became beggars and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  went from being a world famous exporter of finished cloth into an importer when from having of the world trade to less than meanwhile colonialists like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     robert
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  clive bought their rotten boroughs in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     england
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on the proceeds of their loot in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  while taking the hindi word loot into their dictionary as well as their habits and the
# <mark

# %%
comp_labels_1 = [x.label_ for x in doc2.ents]
comp_labels_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b9441ce8b85c> in <cell line: 1>()
# ----> 1 comp_labels_1 = [x.label_ for x in doc2.ents]
#       2 comp_labels_1
#
# NameError: name 'doc2' is not defined

# %%
from sklearn import metrics
manual_labels_1 =['PERSON', 'ORG', 'ORG', 'PERSON','DATE', 'ORG', 'ORG','ORDINAL','ORDINAL','PERSON', 'NORP', 'FAC', 'ORG', 'GPE', 'LOC', 'PRODUCT', 'EVENT']


# PERSON, NORP, FAC, ORG, GPE, LOC, PRODUCT, EVENT, WORK_OF_ART, LAW, LANGUAGE, DATE, TIME, PERCENT, MONEY, QUANTITY, ORDINAL, CARDINAL

print(metrics.classification_report(manual_labels_1,comp_labels_1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-49234e6770ad> in <cell line: 7>()
#       5 # PERSON, NORP, FAC, ORG, GPE, LOC, PRODUCT, EVENT, WORK_OF_ART, LAW, LANGUAGE, DATE, TIME, PERCENT, MONEY, QUANTITY, ORDINAL, CARDINAL
#       6
# ----> 7 print(metrics.classification_report(manual_labels_1,comp_labels_1))
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2308     """
#    2309
# -> 2310     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2311
#    2312     if labels is None:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      84     y_pred : array or indicator matrix
#      85     """
# ---> 86     check_consistent_length(y_true, y_pred)
#      87     type_true = type_of_target(y_true, input_name="y_true")
#      88     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [17, 31]
